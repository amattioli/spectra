# %% [markdown]
# # [V1770 Cygni](../../Costellazioni/Cygnus/V1770_Cyg.html) del [18/07/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
wavelength, flux = spec.load("_v1770cyg_20250718_909-rect.fit")
flux = spec.cleanup_flux(flux)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=120.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-07-18T21:48:49.6965084Z
# - EndCapture=2025-07-18T22:18:58.7094842Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 15 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5600, 5700):.1f}")
# Out:
# SNR Reale stimato: 280.0

# %% [markdown]
# ![_v1770cyg_20250718_909.png](attachment:_v1770cyg_20250718_909.png)

# %% [markdown]
# ## Rectified Spectrum [download](_v1770cyg_20250718_909-rect.fit)

# %% [markdown]
# ![_v1770cyg_20250718_909-rect.png](attachment:_v1770cyg_20250718_909-rect.png)
