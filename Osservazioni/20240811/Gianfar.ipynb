# %% [markdown]
# # [Gianfar - Lambda Draconis](../../Costellazioni/Draco/Gianfar.html) del [11/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=125
# - Exposure=30.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-11T20:07:03.6181628Z
# - EndCapture=2024-08-11T20:32:30.5869200Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 8 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Merak della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-merak.png](attachment:meanprofil-resp-corr-merak.png)

# %% [markdown]
# ### Zoom 410 - 510 nm

# %% [markdown]
# ![meanprofil-resp-corr-merak-410-510.png](attachment:meanprofil-resp-corr-merak-410-510.png)
