# %% [markdown]
# # Zosma - Delta [Leonis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1u_bYqb4VN2Qe26CtNbyA39-cbxVOVM6ni8HAN_QZrEk/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=zosma&submit=SIMBAD+search): A5IV(n)

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [30/04/2025](../../Osservazioni/20250430/Zosma.html)
