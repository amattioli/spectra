# %% [markdown]
# # [Lambda Cassiopeiae](../../Costellazioni/Cassiopeia/Lambda_Cas.html) del [19/09/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=70.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-09-19T19:43:01.5116774Z
# - EndCapture=2025-09-19T20:18:20.6163264Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_lambdacas_20250919_822.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,25.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_lambdacas_20250919_822-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6000, 6200):.1f}")
# Out:
# SNR Reale stimato: 916.8

# %%
spectral_lines_summary = pd.read_csv('Lambda Cas spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Lambda Cas spec - 2025-09-19.csv', usecols=[0, 1, 17], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.40,1.3))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.45,1.3))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.45,1.3))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.45,1.3))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.45,1.3))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.7,1.2))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.7,1.2))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.6,1.2))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Lambda Cas spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)

df
# Out:
# fwhm_use =  15.770553150000069
# amp = -12.609778607342982
# mu = 4101.881778170895
# sigma = 2.582361995559607
# gamma = 6.448639688154355
# offset = 1.0112526224666063
# fwhm_use =  16.248448700000154
# amp = -10.903322386253743
# mu = 4340.655591279836
# sigma = 4.1145039477187755
# gamma = 4.788575995458094
# offset = 1.011771455602355
# fwhm_use =  17.204239800000323
# amp = -10.570495196299417
# mu = 4861.391224213006
# sigma = 4.290842242248193
# gamma = 5.311980253888025
# offset = 1.0112565533930966
# fwhm_use =  21.027404200000092
# amp = -9.720570547094264
# mu = 6562.5937070334085
# sigma = 4.404667916175528
# gamma = 7.568088971701359
# offset = 1.0104867856527582
# fwhm_use =  7.646328799999992
# amp = -0.05798660805162517
# mu = 4026.5431788016504
# sigma = 3.333511513856647
# offset = 1.012942135737018
# fwhm_use =  10.991597649999676
# amp = -0.029331872317774125
# mu = 4388.467975509378
# sigma = 4.096143652662794
# offset = 1.012267924700339
# ...
