# %% [markdown]
# # BK [Camelopardalis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=bk+Cam&submit=SIMBAD+search): B2.5Vn(e)

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [02/05/2025](../../Osservazioni/20250502/BK_Cam.html)
