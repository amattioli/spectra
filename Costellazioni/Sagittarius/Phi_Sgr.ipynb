# %% [markdown]
# # Phi [Sagittarii](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1uigsB-7qWw4hWBdO5XM2Vo6fi0B5WPXPrawhrvBXHDY/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=phi+sgr&submit=SIMBAD+search): B8III

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [30/08/2025](../../Osservazioni/20250830/Phi_Sgr.html)
