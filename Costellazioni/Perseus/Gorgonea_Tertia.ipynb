# %% [markdown]
# # Gorgonea Tertia - Rho [Persei](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione Simbad: M4+IIIa

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [16/12/2024](../../Osservazioni/20241216/Gorgonea_Tertia.html)
