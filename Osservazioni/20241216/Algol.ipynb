# %% [markdown]
# # [Algol - Beta Persei](../../Costellazioni/Perseus/Algol.html) del [16/12/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=25.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-12-16T17:57:30.3371533Z Julian 2460661.248268
# - EndCapture=2024-12-16T18:06:02.6361480Z Julian 2460661.254197

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 15 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_algol_20241216_748.png](attachment:_algol_20241216_748.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![_algol_20241216_748-resp-corr-self.png](attachment:_algol_20241216_748-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_algol_20241216_748-rect.png](attachment:_algol_20241216_748-rect.png)

# %% [markdown]
# ### Zoom  390 - 460 nm

# %% [markdown]
# ![_algol_20241216_748-rect-390-460.png](attachment:_algol_20241216_748-rect-390-460.png)

# %% [markdown]
# ### Zoom  460 - 530 nm

# %% [markdown]
# ![_algol_20241216_748-rect-460-530.png](attachment:_algol_20241216_748-rect-460-530.png)
