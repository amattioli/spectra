# %% [markdown]
# # [Vega - Alpha Lyrae](../../Costellazioni/Lyra/Vega.html) del [23/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=2.500s
# - Brightness=0
# - Temperature=0
# - StartCapture=2024-08-23T20:14:49.0299275Z
# - EndCapture=2024-08-23T20:19:53.8226170Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 8 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil-resp-corr-self.png](attachment:meanprofil-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)

# %% [markdown]
# ### Zoom  390 - 540 nm

# %% [markdown]
# ![meanprofil-rect-390-540.png](attachment:meanprofil-rect-390-540.png)
