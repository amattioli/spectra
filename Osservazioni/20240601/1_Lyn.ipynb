# %% [markdown]
# # [1 Lyncis](../../Costellazioni/Lynx/1_Lyn.html) del [01/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=30.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-01T21:09:07.5609602Z
# - EndCapture=2024-06-01T22:00:02.5378823Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini.
# Visto il tempo lungo di esposizione e il gain abbastanza alto ho tentato per la prima volta di sottrarre i dark (utilizzando Siril) e ho ottenuto un miglioramento significativo

# %% [markdown]
# ![pp_1%20lyn%20spec_media-raw.png](attachment:pp_1%20lyn%20spec_media-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di 2 Lyn della stessa serata

# %% [markdown]
# ![pp_1%20lyn%20spec_media-resp-corr-2lyn-3.png](attachment:pp_1%20lyn%20spec_media-resp-corr-2lyn-3.png)
