# %% [markdown]
# # [VY Ursae Majoris](../../Costellazioni/Ursa_Major/VY_UMa.html) del [10/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=60.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-10T21:29:28.4990752Z
# - EndCapture=2024-08-10T22:51:12.4040322Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![pp_lights_00019.png](attachment:pp_lights_00019.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dalo spettro di Merak della stessa serata

# %% [markdown]
# ![pp_lights_00019-resp-corr-merak.png](attachment:pp_lights_00019-resp-corr-merak.png)
