# %% [markdown]
# # Mirfak - Alpha Per

# %% [markdown]
# ## Descrizione

# %% [markdown]
# - Mv = 1.79 (Simbad)
# - Classe spettrale = F5Ib (Simbad)
# - Teff = 6370K (SkySafari 6)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Usando lo spettro sottostante (versione linearizzata dell'osservazione del 28/04/2024):
# - Ca II H e K visibili
# - Ca II H/Hgamma > 1
# - Ca II K/H ~ 1
# - G Band visibile
#
# Dunque: F3-F9
#
# Classificazione Simbad: F5I

# %% [markdown]
# ![2024-04-28-2002_5-mirfak%20spec_3-lin.png](attachment:2024-04-28-2002_5-mirfak%20spec_3-lin.png)

# %% [markdown]
# ## Osservazione del 27/04/2024

# %% [markdown]
# ![2024-04-27-2019_7-mirfak%20spec_14-resp-corr-self.png](attachment:2024-04-27-2019_7-mirfak%20spec_14-resp-corr-self.png)

# %% [markdown]
# Roma Cinecittà. Osservazione effettuata dall'interno di casa
# - Celestron C8 su CEM70
# - Camera ZWO ASI533MM
# - Star Analyser 200 + Grism
# - Calibrazione del flusso su se stessa

# %% [markdown]
# ## Osservazione del 28/04/2024

# %% [markdown]
# ![2024-04-28-2002_5-mirfak%20spec_3-resp-corr-self.png](attachment:2024-04-28-2002_5-mirfak%20spec_3-resp-corr-self.png)

# %% [markdown]
# Roma Cinecittà. Osservazione effettuata dall'interno di casa
# - Celestron C8 su CEM70
# - Camera ZWO ASI533MM
# - Star Analyser 200 + Grism
# - Calibrazione del flusso su se stessa

# %% [markdown]
# ## Osservazione del 29/04/2024

# %% [markdown]
# ![2024-04-29-1923_6-mirfak%20spec_2-resp-corr-self.png](attachment:2024-04-29-1923_6-mirfak%20spec_2-resp-corr-self.png)

# %% [markdown]
# Roma Cinecittà. Osservazione effettuata dall'interno di casa
# - Celestron C8 su CEM70
# - Camera ZWO ASI533MM
# - Star Analyser 200 + Grism
# - Calibrazione del flusso su se stessa
