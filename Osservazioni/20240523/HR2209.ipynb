# %% [markdown]
# # [HR2209](../../Costellazioni/Camelopardalis/HR2209.html) del [23/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-5.1
# - StartCapture=2024-05-23T20:09:48.4185536Z
# - EndCapture=2024-05-23T20:35:45.0559059Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 4 immagini

# %% [markdown]
# ![2024-05-23-2022_9-hr%202209%20spec_media-raw-tilt.png](attachment:2024-05-23-2022_9-hr%202209%20spec_media-raw-tilt.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# ![2024-05-23-2022_9-hr%202209%20spec_media-resp-corr-self-tilt.png](attachment:2024-05-23-2022_9-hr%202209%20spec_media-resp-corr-self-tilt.png)
