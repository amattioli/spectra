# %% [markdown]
# # [Alpha Delphini](../../../Costellazioni/Delphinus/Alpha_Del.html) del [04/11/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=25.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-11-04T17:27:06.2274505Z
# - EndCapture=2025-11-04T17:39:53.5513387Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 26 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_alphadel_20251104_730.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,27.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_alphadel_20251104_730-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6695, 6785):.1f}")
# Out:
# SNR Reale stimato: 618.0

# %%
spectral_lines_summary = pd.read_csv('Alpha Del spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Alpha Del spec - 2025-11-04.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.50,1.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.60,1.20))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.60,1.20))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.60,1.20))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.60,1.20))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.60,1.20))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.60,1.20))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Alpha Del spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)
df = df.sort_values('Lambda fit')
df
# Out:
# fwhm_use =  14.689149749992794
# amp = -12.351017829435825
# mu = 4101.471789571215
# sigma = 3.35230273457209
# gamma = 5.0715102325633845
# offset = 1.0082259534838387
# fwhm_use =  15.178788074992553
# amp = -12.603038481902807
# mu = 4340.353758526649
# sigma = 2.853700114753239
# gamma = 5.802181016601387
# offset = 1.005167445011398
# fwhm_use =  16.158064724992073
# amp = -12.723499413457514
# mu = 4860.939257512558
# sigma = 2.631218710240313
# gamma = 6.64179527797132
# offset = 1.0066738008484193
# fwhm_use =  18.606256349990872
# amp = -11.09950828643198
# mu = 6561.952032972554
# sigma = 3.54874013892291e-05
# gamma = 8.875311888183438
# offset = 0.9980088310995093
# fwhm_use =  8.323851524995916
# amp = -0.0482740318195911
# mu = 4026.6570679167467
# sigma = 4.001205569401678
# offset = 1.0093591142275435
# fwhm_use =  8.323851524995916
# amp = -0.021913343353644088
# mu = 6345.451885741646
# sigma = 3.7133958114260674
# offset = 1.0002715471745653
# fwhm_use =  11.261681474994475
# amp = -0.018417167556305698
# mu = 6370.906182006316
# sigma = 3.517943225819034
# offset = 0.9982373624913301
# fwhm_use =  6.854936549996637
# amp = -0.08781535943082118
# mu = 3933.596953515032
# sigma = 2.664183477859436
# offset = 1.0082007196789158
# amp = -0.029709308260185866
# mu = 4385.836125905549
# sigma = 2.8497443226103627
# offset = 1.008291141180481
# amp = -0.0161411524641838
# mu = 4393.000000000001
# sigma = 4.294414388856157
# offset = 1.008291141180481
# amp = -0.0380600029796432
# mu = 4470.880160734716
# sigma = 2.7860150704168096
# offset = 1.007474616716097
# amp = -0.06171260107617984
# mu = 4481.420974255827
# sigma = 2.836670014194208
# offset = 1.007474616716097
#           Line   Lambda min   Lambda fit         EW    EW_Err       FWHM  \
# 7   Ca II 3934  3933.447682  3933.596954   0.581671  0.012390   6.274152
# 4    He I 4026  4025.989325  4026.657068   0.479677  0.014482   9.422839
# 0    H$\delta$  4101.393627  4101.471790  12.250248  0.036706  14.620303
# 1    H$\gamma$  4339.847492  4340.353759  12.538248  0.049239  14.824907
# 8    He I 4388  4387.900000  4385.836126   0.210476  0.016166   6.711148
# 9      Unknown  4396.000000  4393.000000   0.172323  0.019474  10.113346
# 10   He I 4471  4471.480000  4470.880161   0.263820  0.012371   6.561065
# 11  Mg II 4481  4481.260000  4481.420974   0.435550  0.014506   6.680358
# 2     H$\beta$  4860.333031  4860.939258  12.639148  0.038034  15.854172
# 5   Si II 6347  6345.895709  6345.451886   0.203916  0.014856   8.745047
# 6   Si II 6371  6371.846540  6370.906182   0.162693  0.010608   8.284756
# 3    H$\alpha$  6561.826210  6561.952033  11.121653  0.045812  17.750678
#
#     FWHM_Err
# 7   0.119313
# 4   0.414360
# 0   0.043978
# 1   0.055992
# 8   0.431840
# 9   1.282725
# 10  0.321994
# 11  0.292604
# 2   0.072967
# 5   0.775027
# 6   0.463719
# 3   0.116032
