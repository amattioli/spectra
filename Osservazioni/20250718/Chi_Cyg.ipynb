# %% [markdown]
# # [Chi Cygni](../../Costellazioni/Cygnus/Chi_Cyg.html) del [18/07/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
wavelength, flux = spec.load("_chicyg_20250718_847.fit")
flux = spec.cleanup_flux(flux)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=180.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-07-18T20:19:16.6583448Z
# - EndCapture=2025-07-18T21:04:03.3964712Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 15 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5950, 6050):.1f}")
# Out:
# SNR Reale stimato: 106.7

# %% [markdown]
# ![_chicyg_20250718_847.png](attachment:_chicyg_20250718_847.png)

# %% [markdown]
# ### Zoom  370 - 490 nm

# %% [markdown]
# ![_chicyg_20250718_847-370-490.png](attachment:_chicyg_20250718_847-370-490.png)

# %% [markdown]
# ### Zoom  490 - 610 nm

# %% [markdown]
# ![_chicyg_20250718_847-490-610.png](attachment:_chicyg_20250718_847-490-610.png)

# %% [markdown]
# ### Zoom 610 - 730 nm

# %% [markdown]
# ![_chicyg_20250718_847-610-730.png](attachment:_chicyg_20250718_847-610-730.png)
