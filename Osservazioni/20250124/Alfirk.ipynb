# %% [markdown]
# # [Alfirk - Beta Cephei](../../Costellazioni/Cepheus/Alfirk.html) del [24/01/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=20
# - Exposure=270.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2025-01-24T20:52:41.4158434Z
# - EndCapture=2025-01-24T21:42:52.4516183Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 9 immagini. Applicati dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_alfirk_20250124_901.png](attachment:_alfirk_20250124_901.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Alderamin della stessa serata

# %% [markdown]
# ![_alfirk_20250124_901-resp-corr-alderamin.png](attachment:_alfirk_20250124_901-resp-corr-alderamin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_alfirk_20250124_901-rect.png](attachment:_alfirk_20250124_901-rect.png)

# %% [markdown]
# ### Zoom  360 - 400 nm

# %% [markdown]
# ![_alfirk_20250124_901-rect-360-400.png](attachment:_alfirk_20250124_901-rect-360-400.png)

# %% [markdown]
# ### Zoom  400 - 450 nm

# %% [markdown]
# ![_alfirk_20250124_901-rect-400-450.png](attachment:_alfirk_20250124_901-rect-400-450.png)

# %% [markdown]
# ### Zoom  450 - 500 nm

# %% [markdown]
# ![_alfirk_20250124_901-rect-450-500.png](attachment:_alfirk_20250124_901-rect-450-500.png)

# %% [markdown]
# ### Zoom  550 - 680 nm

# %% [markdown]
# ![_alfirk_20250124_901-rect-550-680.png](attachment:_alfirk_20250124_901-rect-550-680.png)
