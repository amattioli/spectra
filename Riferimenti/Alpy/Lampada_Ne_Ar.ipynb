# %% [markdown]
# # Lampada di calibrazione Ne/Ar

# %% [markdown]
# ## Spettro 390-800

# %% [markdown]
# ![frame_00001-labels.png](attachment:frame_00001-labels.png)

# %% [markdown]
# ## Spettro 380-570

# %% [markdown]
# ![frame_00001-labels-380-570.png](attachment:frame_00001-labels-380-570.png)
