# %% [markdown]
# # Procyon - Alpha [Canis Minoris](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1tRS407Z__m_F9wSYYuRMuUIVnUrL2F9B2ZEaow4SaG4/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=procyon&submit=SIMBAD+search): F5IV-V+DQZ

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [21/02/2025](../../Osservazioni/20250221/Procyon.html)
