# %% [markdown]
# # [Sheliak - Beta Lyrae](../../Costellazioni/Lyra/Sheliak.html) del [15/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=30.000s
# - Brightness=5
# - Temperature=-5.1
# - StartCapture=2024-11-15T17:36:21.8469159Z
# - EndCapture=2024-11-15T17:57:14.4705969Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 41 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Vega della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-vega.png](attachment:pp_lights_stacked-resp-corr-vega.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 510 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-510.png](attachment:pp_lights_stacked-rect-400-510.png)
