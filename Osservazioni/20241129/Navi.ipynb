# %% [markdown]
# # [Navi - Gamma Cassiopeiae](../../Costellazioni/Cassiopeia/Navi.html) del [29/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=35.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-11-29T18:39:17.1099056Z
# - EndCapture=2024-11-29T18:51:08.5375291Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 14 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Segin della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-segin.png](attachment:pp_lights_stacked-resp-corr-segin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)
