# %% [markdown]
# # 36 Camelopardalis del [04/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=300
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-5.1
# - StartCapture=2024-05-04T22:02:06.3166454Z
# - EndCapture=2024-05-04T22:29:34.0153814Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 5 immagini

# %% [markdown]
# ![2024-05-04-2216_0-36%20cam%20spec_media-raw.png](attachment:2024-05-04-2216_0-36%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw spectrum per la risposta calcolata tramite lo spettro di Beta Cam della stessa serata

# %% [markdown]
# ![2024-05-04-2216_0-36%20cam%20spec_media-resp-corr-betacam-spline.png](attachment:2024-05-04-2216_0-36%20cam%20spec_media-resp-corr-betacam-spline.png)
