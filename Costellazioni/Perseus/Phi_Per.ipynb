# %% [markdown]
# # Phi Persei

# %% [markdown]
# ## Descrizione

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=phi+per&submit=SIMBAD+search): B1.5V:e-shell

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [07/04/2025](../../Osservazioni/20250407/Phi_Per.html)
