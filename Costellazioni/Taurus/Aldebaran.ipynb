# %% [markdown]
# # Aldebaran - Alpha [Tauri](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=elnath&submit=SIMBAD+search): K5+III

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [29/01/2025](../../Osservazioni/20250129/Aldebaran.html)
