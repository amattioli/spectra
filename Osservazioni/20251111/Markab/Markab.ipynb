# %% [markdown]
# # [Markab - Alpha Pegasi](../../../Costellazioni/Pegasus/Markab.html) del [11/11/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-11-11T17:17:50.8363647Z
# - EndCapture=2025-11-11T17:35:21.9822933Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 49 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_markb_20251111_721.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,25.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_markb_20251111_721-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5720, 5820):.1f}")
# Out:
# SNR Reale stimato: 802.1

# %%
spectral_lines_summary = pd.read_csv('Markab spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Markab spec - 2025-11-11.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.50,1.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.60,1.20))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.60,1.20))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.60,1.20))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.60,1.20))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.60,1.20))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.60,1.20))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Markab spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)
df = df.sort_values('Lambda fit')
df
# Out:
# fwhm_use =  16.129016900014904
# amp = -14.270918621416614
# mu = 4101.866306090893
# sigma = 3.489312053516012
# gamma = 5.510402281945853
# offset = 1.004538262077872
# fwhm_use =  16.129016900014904
# amp = -14.306427833270654
# mu = 4340.721821845084
# sigma = 3.3839369442142226
# gamma = 5.978924666570053
# offset = 1.0051551037959665
# fwhm_use =  17.552165450017128
# amp = -14.012125097169594
# mu = 4861.480333829375
# sigma = 3.4386690428266533
# gamma = 6.655334342269172
# offset = 1.00438880223674
# fwhm_use =  18.026548300016657
# amp = -12.267770280613789
# mu = 6563.374638181128
# sigma = 0.0006330209376095791
# gamma = 9.111368343477995
# offset = 1.0004403497797718
# fwhm_use =  8.064508450006542
# amp = -0.027744886663052748
# mu = 6348.020561057803
# sigma = 2.9572741245020877
# offset = 1.0009409749449127
# fwhm_use =  7.590125600007013
# amp = -0.020704833849313625
# mu = 6372.350588916144
# sigma = 3.320323643738441
# offset = 1.0009409749449127
# fwhm_use =  6.641359900006137
# amp = -0.11750862876624814
# mu = 3933.7282918458113
# sigma = 2.5570219239779894
# offset = 1.0046474793105846
# amp = -0.022977672464459437
# mu = 4470.690519903624
# sigma = 3.4258692794297865
# offset = 1.0043215526225124
# amp = -0.05658922399520249
# mu = 4481.36691479791
# sigma = 2.3785046055093058
# offset = 1.0043215526225124
# amp = -0.01688073068208259
# mu = 4488.0174010689325
# sigma = 3.861700720904426
# offset = 1.0043215526225124
#                   Line   Lambda min   Lambda fit         EW    EW_Err  \
# 6           Ca II 3934  3933.320988  3933.728292   0.749688  0.011856
# 0            H$\delta$  4102.201283  4101.866306  14.206446  0.039923
# 1            H$\gamma$  4340.341474  4340.721822  14.233055  0.038056
# 7           Ti II 4468  4468.500000  4470.690520   0.196469  0.015909
# 8           Mg II 4481  4481.260000  4481.366915   0.335935  0.048034
# 9  Ti II/Fe II 4488-89  4488.500000  4488.017401   0.162700  0.054163
# 2             H$\beta$  4861.213843  4861.480334  13.950897  0.046373
# 4           Si II 6347  6347.929695  6348.020561   0.205474  0.013871
# 5           Si II 6371  6372.597603  6372.350589   0.172161  0.012432
# 3            H$\alpha$  6563.773892  6563.374638  12.262371  0.046246
#
#         FWHM  FWHM_Err
# 6   6.021787  0.085441
# 0  15.577899  0.042474
# 1  16.112217  0.052628
# 7   8.067922  0.533463
# 8   5.601378  0.399475
# 9   9.094305  1.908408
# 2  17.311202  0.075789
# 4   6.964381  0.424635
# 5   7.819362  0.595773
# 3  18.222792  0.092844
