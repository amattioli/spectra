# %% [markdown]
# # [Albireo 1 - Beta Cygni](../../Costellazioni/Cygnus/Albireo_1.html) del [01/08/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=50
# - Exposure=60.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-08-01T21:01:14.0986453Z
# - EndCapture=2025-08-01T21:21:25.6153806Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 20 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_albireo1_20250801_876.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,5.0))

# %% [markdown]
# ## Rectified Spectrum [download](_albireo1_20250801_876-rect.fit)

# %%
wavelength, flux = spec.load("_albireo1_20250801_876-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6000, 6200):.1f}")
# Out:
# SNR Reale stimato: 67.0

# %%
spectral_lines_summary = pd.read_csv('Albireo 1 spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Albireo 1 spec - 2025-08-01.csv', usecols=[0, 1, 13], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3770,7000), (0.3,1.5))

# %% [markdown]
# ### Zoom  380 - 420 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3780,4220), (0.3,1.5))

# %% [markdown]
# ### Zoom  420 - 450 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4180,4520), (0.4,1.5))

# %% [markdown]
# ### Zoom 450 - 480 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4480,4820), (0.4,1.5))

# %% [markdown]
# ### Zoom  480 - 510 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4780,5120), (0.4,1.5))

# %% [markdown]
# ### Zoom  510 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5080,5420), (0.4,1.5))

# %% [markdown]
# ### Zoom  540 - 570 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,5720), (0.4,1.5))

# %% [markdown]
# ### Zoom  570 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5680,6020), (0.4,1.5))

# %% [markdown]
# ### Zoom  600 - 640 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6420), (0.4,1.5))

# %% [markdown]
# ### Zoom  640 - 680 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (6380,6820), (0.4,1.5))
