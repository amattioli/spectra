# %% [markdown]
# # [Zeta Cassiopeiae](../../Costellazioni/Cassiopeia/Zeta_Cas.html) del [29/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=90.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-11-29T17:20:15.3270322Z
# - EndCapture=2024-11-29T17:50:27.3220250Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 20 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Segin della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-segin.png](attachment:pp_lights_stacked-resp-corr-segin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 510 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-510.png](attachment:pp_lights_stacked-rect-400-510.png)
