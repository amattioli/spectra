# %% [markdown]
# # [CS Cam](../../../Costellazioni/Camelopardalis/CS_Cam.html) del [31/10/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-10-31T18:02:31.9105084Z
# - EndCapture=2025-10-31T18:12:49.9288061Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_cscam_20251031_752.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,12.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_cscam_20251031_752-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6695, 6795):.1f}")
# Out:
# SNR Reale stimato: 811.6

# %%
spectral_lines_summary = pd.read_csv('CS Cam spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('CS Cam spec - 2025-10-31.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.50,1.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.50,1.25))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.50,1.25))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.70,1.2))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.75,1.15))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.70,1.15))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.70,1.15))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('CS Cam spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)
df = df.sort_values('Lambda fit')
df
# Out:
# fwhm_use =  7.5
# amp = -2.2558501494248504
# mu = 4101.189005455679
# sigma = 2.487881023942471
# gamma = 0.9116735261421408
# offset = 0.9976506807876419
# fwhm_use =  7.5
# amp = -1.8483242429387698
# mu = 4861.070499953937
# sigma = 2.4096950376555792
# gamma = 1.1244666934278007
# offset = 0.999618427685915
# fwhm_use =  7.719411764705883
# amp = -0.6964274896206073
# mu = 6561.367806021963
# sigma = 0.00010767089288377706
# gamma = 3.7648112194836036
# offset = 0.9976170659668055
# C:\Users\andrea\personal\physics\astro\spettroscopia\ipynb\Osservazioni\20251031\CS_Cam\../../../src\spectral_lines.py:228: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(
# fwhm_use =  7.465882352941176
# amp = -0.10512820003577882
# mu = 6346.404444565203
# sigma = 2.708081436548172
# offset = 0.9996394167066616
# fwhm_use =  7.4947058823529416
# amp = -0.08574036750883024
# mu = 6370.792338646424
# sigma = 2.749870261769442
# offset = 0.9995770698971956
# fwhm_use =  6.5
# amp = -0.11796916374439265
# mu = 3932.7072929860947
# sigma = 2.991743034947296
# offset = 0.9983786759042468
# amp = -0.2597840041108685
# mu = 4340.273092429142
# sigma = 2.9492102584318247
# offset = 0.9983632382675698
# amp = -0.04058804942175148
# mu = 4351.397837671796
# sigma = 2.8169384031933373
# offset = 0.9983632382675698
# amp = -0.0476634164817868
# mu = 4024.874989246791
# sigma = 2.013860189012424
# offset = 0.9968716453448014
# amp = -0.016907191744725856
# mu = 4035.9999999944116
# sigma = 8.05894842013237
# offset = 0.9968716453448014
# amp = -0.0530172590828606
# mu = 4386.280410153501
# sigma = 2.595752696975742
# offset = 0.9989473940204044
# amp = -0.02420265075757375
# mu = 4393.000000000001
# sigma = 2.3407358534080758
# offset = 0.9989473940204044
# amp = -0.04459672396113593
# mu = 4471.446578937445
# sigma = 2.3757192782295142
# offset = 0.9995382495764751
# amp = -0.10037481411590769
# mu = 4481.1611454608665
# sigma = 2.2767818478330684
# offset = 0.9995382495764751
#           Line  Lambda min   Lambda fit        EW    EW_Err       FWHM  \
# 5   Ca II 3934     3933.00  3932.707293  0.886110  0.026169   7.045555
# 8    He I 4026     4025.50  4024.874989  0.241360  0.011003   4.742641
# 9   Fe II 4033     4033.00  4036.000000  0.342610  0.020999  18.978824
# 0    H$\delta$     4101.00  4101.189005  2.261162  0.027610   6.894413
# 6    H$\gamma$     4340.50  4340.273092  1.923621  0.012194   6.945390
# 7   Fe II 4352     4352.00  4351.397838  0.287063  0.016604   6.633890
# 10   He I 4388     4387.90  4386.280410  0.345325  0.016452   6.112998
# 11     Unknown     4396.00  4393.000000  0.142155  0.012667   5.512433
# 12   He I 4471     4471.48  4471.446579  0.265698  0.010174   5.594819
# 13  Mg II 4481     4481.26  4481.161145  0.573108  0.012701   5.361821
# 1     H$\beta$     4861.50  4861.070500  1.849030  0.026011   6.972400
# 3   Si II 6347     6346.00  6346.404445  0.713884  0.012719   6.377532
# 4   Si II 6371     6370.50  6370.792339  0.591250  0.014440   6.475944
# 2    H$\alpha$     6561.50  6561.367806  0.698091  0.025471   7.529645
#
#     FWHM_Err
# 5   0.331549
# 8   0.173827
# 9   0.891085
# 0   0.062966
# 6   0.059198
# 7   0.419666
# 10  0.265021
# 11  0.460240
# 12  0.262177
# 13  0.133118
# 1   0.071935
# 3   0.122047
# 4   0.175250
# 2   0.374171
