# %% [markdown]
# # [Porrima - Gamma Virginis](../../Costellazioni/Virgo/Porrima.html) del [24/05/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=120.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-05-24T20:14:04.8616435Z
# - EndCapture=2025-05-24T20:44:13.3946640Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 15 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_porrima_20250524_843.png](attachment:_porrima_20250524_843.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_porrima_20250524_843-rect.png](attachment:_porrima_20250524_843-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-370-400.png](attachment:_porrima_20250524_843-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-400-430.png](attachment:_porrima_20250524_843-rect-400-430.png)

# %% [markdown]
# ### Zoom  430 - 460 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-430-460.png](attachment:_porrima_20250524_843-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 490 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-460-490.png](attachment:_porrima_20250524_843-rect-460-490.png)

# %% [markdown]
# ### Zoom  490 - 520 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-490-520.png](attachment:_porrima_20250524_843-rect-490-520.png)

# %% [markdown]
# ### Zoom  520 - 550 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-520-550.png](attachment:_porrima_20250524_843-rect-520-550.png)

# %% [markdown]
# ### Zoom  550 - 580 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-550-580.png](attachment:_porrima_20250524_843-rect-550-580.png)

# %% [markdown]
# ### Zoom  580 - 620 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-580-620.png](attachment:_porrima_20250524_843-rect-580-620.png)

# %% [markdown]
# ### Zoom  620 - 660 nm

# %% [markdown]
# ![_porrima_20250524_843-rect-620-660.png](attachment:_porrima_20250524_843-rect-620-660.png)
