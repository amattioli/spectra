# %% [markdown]
# # Pi [Scorpii](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1_Jqcb-kv1aCVJlQn4W_C0whKCNuF5007n9vpedYSib8/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=pi+sco&submit=SIMBAD+search): B1V+B2:V

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [28/06/2025](../../Osservazioni/20250628/Pi_Sco.html)
