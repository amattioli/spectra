# %% [markdown]
# # [Caph - Beta Cassiopeiae](../../Costellazioni/Cassiopeia/Caph.html) del [30/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=18.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-30T21:24:11.1275419Z
# - EndCapture=2024-08-30T21:55:04.4009043Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil-resp-corr-self.png](attachment:meanprofil-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)

# %% [markdown]
# ### Zoom  410 - 520 nm

# %% [markdown]
# ![meanprofil-rect-410-520.png](attachment:meanprofil-rect-410-520.png)
