# %% [markdown]
# # [Regulus - Alpha Leonis](../../Costellazioni/Leo/Regulus.html) del [21/02/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=25.000s
# - Brightness=5
# - Temperature=-9.9
# - StartCapture=2025-02-21T19:53:04.3693958Z
# - EndCapture=2025-02-21T20:05:52.8800552Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 21 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_regulus_20250221_835.png](attachment:_regulus_20250221_835.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_regulus_20250221_835-rect.png](attachment:_regulus_20250221_835-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_regulus_20250221_835-rect-370-400.png](attachment:_regulus_20250221_835-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 440 nm

# %% [markdown]
# ![_regulus_20250221_835-rect-400-440.png](attachment:_regulus_20250221_835-rect-400-440.png)

# %% [markdown]
# ### Zoom  440 - 500 nm

# %% [markdown]
# ![_regulus_20250221_835-rect-440-500.png](attachment:_regulus_20250221_835-rect-440-500.png)

# %% [markdown]
# ### Zoom  500 - 560 nm

# %% [markdown]
# ![_regulus_20250221_835-rect-500-560.png](attachment:_regulus_20250221_835-rect-500-560.png)

# %% [markdown]
# ### Zoom  560 - 670 nm

# %% [markdown]
# ![_regulus_20250221_835-rect-560-670.png](attachment:_regulus_20250221_835-rect-560-670.png)
