# %% [markdown]
# # [Mirfak - Alpha Persei](../../Costellazioni/Perseus/Mirfak.html) del [16/12/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=90.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-12-16T17:06:07.1137387Z
# - EndCapture=2024-12-16T17:21:12.8964969Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 10 immagini. Applicati dark e flat

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![pp_lights_stacked-resp-corr-self.png](attachment:pp_lights_stacked-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 470 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-470.png](attachment:pp_lights_stacked-rect-400-470.png)

# %% [markdown]
# ### Zoom  470 - 540 nm

# %% [markdown]
# ![pp_lights_stacked-rect-470-540.png](attachment:pp_lights_stacked-rect-470-540.png)
