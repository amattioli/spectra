# %% [markdown]
# # Osservazioni del 04/11/2025

# %% [markdown]
# ## Setup

# %% [markdown]
# - Ottica: Celestron C8
# - Montatura: iOptron CEM70
# - Camera: ZWO ASI533MM Pro
# - Guida: Alpy 600 guide module + ASI585MC
# - Spettroscopio: Alpy 600 con fenditura da 10$\mu$m + modulo di calibrazione
# - Luogo: Terrazzo lato Cominio

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [Alpha Del](Alpha_Del/Alpha_Del.html)
# - [Beta Del](Beta_Del/Beta_Del.html)
# - [Delta Del](Delta_Del/Delta_Del.html)
