# %% [markdown]
# # Scheat - Beta [Pegasi](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# Scheat, Beta Pegasi is an M2.5 II-III red giant/bright giant.
#
# | VALD field | Value | Source |
# |---|---|---|
# | Teff | 3689 K | consistent across catalog sources |
# | log g | 1.20 | general catalog |
# | Microturbulence | not pinned down precisely — likely ~2–3 km/s given how low log g is (cooler, lower-gravity giants trend higher) | — |
# | [Fe/H] | roughly −0.1 to −0.15 (mildly subsolar) | Hipparcos-derived catalog estimate, modest confidence |
# | v sin i (context) | 9.7 km/s | catalog |
#
#
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/12cTweSbI4CWRFVDvsoWLMWWmde3wANTdlOSg1s0jNGI/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=scheat&submit=SIMBAD+search): M2.5II-III

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [11/11/2025](../../Osservazioni/20251111/Scheat/Scheat.html)
