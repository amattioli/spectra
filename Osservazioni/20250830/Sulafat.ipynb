# %% [markdown]
# # [Sulafat - Gamma Lyrae](../../Costellazioni/Lyra/Sulafat.html) del [30/08/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-08-30T21:53:03.0333186Z
# - EndCapture=2025-08-30T22:03:21.4108107Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_sulafat_20250830_912.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,20.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_sulafat_20250830_912-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5500, 5700):.1f}")
# Out:
# SNR Reale stimato: 1014.0

# %%
spectral_lines_summary = pd.read_csv('Sulafat spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Sulafat spec - 2025-08-30.csv', usecols=[0, 1, 15], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.30,1.3))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.35,1.3))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.6,1.2))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.6,1.2))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.6,1.2))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.7,1.2))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.7,1.3))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.6,1.2))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Sulafat spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)

df
# Out:
# fwhm_use =  11.935131250000268
# amp = -9.370581911226623
# mu = 4101.6570445395155
# sigma = 3.0274893846853805
# gamma = 3.3848363015005276
# offset = 0.9992945505016461
# fwhm_use =  11.935131250000268
# amp = -9.13740093605778
# mu = 4340.460510026438
# sigma = 3.077692741915869
# gamma = 3.4582388347468433
# offset = 0.9996185157324973
# fwhm_use =  13.367346999999427
# amp = -9.566349223653575
# mu = 4861.020542337609
# sigma = 2.899411716403803
# gamma = 4.5047170642990135
# offset = 0.9993671367595927
# fwhm_use =  14.799562750000405
# amp = -9.259646266458507
# mu = 6562.748682634974
# sigma = 0.00013346564179541348
# gamma = 7.101766639127499
# offset = 1.0001432291138295
# fwhm_use =  7.638484000000062
# amp = -0.03309696080909214
# mu = 4026.3371910054266
# sigma = 3.0765529749964293
# offset = 1.000015679264203
# fwhm_use =  6.206268249999994
# amp = -0.0659717208570787
# mu = 3933.438176316988
# sigma = 2.541057203923383
# offset = 1.0004597513801199
# ...
