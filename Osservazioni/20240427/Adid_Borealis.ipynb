# %% [markdown]
# # Adid Borealis 27/04/2024

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=10.000s
# - Brightness=5
# - Temperature=-5.1
#
# - StartCapture=2024-04-27T20:52:58.1388998Z
# - EndCapture=2024-04-27T21:10:39.5787672Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# ![2024-04-27-2101_9-adid%20borealis%20spec_3-raw.png](attachment:2024-04-27-2101_9-adid%20borealis%20spec_3-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ![2024-04-27-2101_9-adid%20borealis%20spec_3-lin.png](attachment:2024-04-27-2101_9-adid%20borealis%20spec_3-lin.png)
