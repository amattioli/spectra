# %% [markdown]
# # HR8403 in [Cygnus](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1dbPPAOsk2_QActVSFXQ9fhng6VwW6zmtxuSzMXdAoIs/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=HR8403&submit=SIMBAD+search): B5III

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [12/09/2025](../../Osservazioni/20250912/HR8403.html)
