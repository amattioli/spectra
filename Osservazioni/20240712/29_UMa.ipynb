# %% [markdown]
# # [29 Ursae Majoris](../../Costellazioni/Ursa_Major/29_UMa.html) del [12/07/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=20.000s
# - Brightness=5
# - Temperature=5
# - StartCapture=2024-07-12T20:28:45.9867400Z
# - EndCapture=2024-07-12T21:03:04.1336136Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 6 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Merak della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-merak.png](attachment:meanprofil-resp-corr-merak.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)
