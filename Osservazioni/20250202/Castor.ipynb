# %% [markdown]
# # [Castor - Alpha Geminorum](../../Costellazioni/Gemini/Castor.html) del [02/02/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=75.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-02-02T18:08:40.3089272Z
# - EndCapture=2025-02-02T18:21:16.3226711Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_castor_20250202_756.png](attachment:_castor_20250202_756.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![_castor_20250202_756-resp-corr-self.png](attachment:_castor_20250202_756-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_castor_20250202_756-rect.png](attachment:_castor_20250202_756-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_castor_20250202_756-rect-370-400.png](attachment:_castor_20250202_756-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_castor_20250202_756-rect-400-430.png](attachment:_castor_20250202_756-rect-400-430.png)

# %% [markdown]
# ### Zoom  430 - 460 nm

# %% [markdown]
# ![_castor_20250202_756-rect-430-460.png](attachment:_castor_20250202_756-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 500 nm

# %% [markdown]
# ![_castor_20250202_756-rect-460-500.png](attachment:_castor_20250202_756-rect-460-500.png)

# %% [markdown]
# ### Zoom  500 - 550 nm

# %% [markdown]
# ![_castor_20250202_756-rect-500-550.png](attachment:_castor_20250202_756-rect-500-550.png)

# %% [markdown]
# ### Zoom  550 - 660 nm

# %% [markdown]
# ![_castor_20250202_756-rect-550-650.png](attachment:_castor_20250202_756-rect-550-650.png)
