# %%
from oospectrum import Spectrum, Spectral_Line, Spectral_Lines_Set

spec = Spectrum()

spec.load("C:\\Users\\andrea\\personal\\physics\\astro\\Tutorial\\_iota_her_20250606_858-rect.fit")

spec.simple_plot(flux_range=(0.0,1.3))

# %%
lines = Spectral_Lines_Set()

lines.load_csv("C:\\Users\\andrea\\personal\\physics\\astro\\Tutorial\\Iota-Her-2025-06-06.csv",[0,1,21])

spec.plot_with_lines(lines, (3680,4020))
