# %% [markdown]
# # [Merak - Beta Ursae Majoris](../../Costellazioni/Ursa_Major/Merak.html) del [11/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=12.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-11T19:49:38.8691742Z
# - EndCapture=2024-08-11T20:00:07.7503760Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil-resp-corr-self.png](attachment:meanprofil-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)

# %% [markdown]
# ### Zoom  400 - 480 nm

# %% [markdown]
# ![meanprofil-rect-400-480.png](attachment:meanprofil-rect-400-480.png)
