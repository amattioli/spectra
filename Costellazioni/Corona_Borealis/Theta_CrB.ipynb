# %% [markdown]
# # Theta [Coronae Borealis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1kP3xKgicdKv5SDJqiVzI1Yih3cIAlPY2e_qggCbuTfk/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=theta+crb&submit=SIMBAD+search): B6Vnne

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [30/05/2025](../../Osservazioni/20250530/Theta_CrB.html)
