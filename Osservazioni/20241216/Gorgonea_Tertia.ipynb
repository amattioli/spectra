# %% [markdown]
# # [Gorgonea Tertia - Rho Persei](../../Costellazioni/Perseus/Gorgonea_Tertia.html) del [16/12/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=130.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-12-16T18:19:20.0588674Z
# - EndCapture=2024-12-16T18:41:06.0238061Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 7 immagini. Applicati dark e flat

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di algol della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-algol.png](attachment:pp_lights_stacked-resp-corr-algol.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  390 - 470 nm

# %% [markdown]
# ![pp_lights_stacked-rect-390-470.png](attachment:pp_lights_stacked-rect-390-470.png)

# %% [markdown]
# ### Zoom  470 - 540 nm

# %% [markdown]
# ![pp_lights_stacked-rect-470-540.png](attachment:pp_lights_stacked-rect-470-540.png)

# %% [markdown]
# ### Zoom  540 - 610 nm

# %% [markdown]
# ![pp_lights_stacked-rect-540-610.png](attachment:pp_lights_stacked-rect-540-610.png)
