# %% [markdown]
# # [Segin - Epsilon Cassiopeiae](../../Costellazioni/Cassiopeia/Segin.html) del [29/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=100.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-11-29T19:01:52.0310079Z
# - EndCapture=2024-11-29T19:35:23.8301933Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 15 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![pp_lights_stacked-resp-corr-self.png](attachment:pp_lights_stacked-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  390 - 510 nm

# %% [markdown]
# ![pp_lights_stacked-rect-390-510.png](attachment:pp_lights_stacked-rect-390-510.png)
