# %% [markdown]
# # Gamma Camelopardalis

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1bWFhvL3nOtNVcAdSS434cDq-54bW6jaY-Xe9UU5z1f4/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=gamma+cam&submit=SIMBAD+search): A2IVn

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [27/04/2024](../../Osservazioni/20240427/Gamma_Cam.html)
# - [24/04/2025](../../Osservazioni/20250424/Gamma_Cam.html)
