# %% [markdown]
# # BE Camelopardalis 27/04/2024

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# ![2024-04-27-2131_1-be%20cam%20spec_1-raw.png](attachment:2024-04-27-2131_1-be%20cam%20spec_1-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ### Full

# %% [markdown]
# ![2024-04-27-2131_1-be%20cam%20spec_1-lin.png](attachment:2024-04-27-2131_1-be%20cam%20spec_1-lin.png)

# %% [markdown]
# ### Crop 5000-6000

# %% [markdown]
# ![2024-04-27-2131_1-be%20cam%20spec_1-lin-crop-500-600.png](attachment:2024-04-27-2131_1-be%20cam%20spec_1-lin-crop-500-600.png)
