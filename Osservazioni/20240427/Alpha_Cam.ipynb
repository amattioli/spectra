# %% [markdown]
# # Alpha Cam 27/04/2027

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-5.3
# - StartCapture=2024-04-27T22:15:03.6065057Z
# - EndCapture=2024-04-27T22:41:00.2723437Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 4 immagini

# %% [markdown]
# ![2024-04-27-2228_1-alfa%20cam%20spec_media-raw.png](attachment:2024-04-27-2228_1-alfa%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ![2024-04-27-2228_1-alfa%20cam%20spec_media-lin.png](attachment:2024-04-27-2228_1-alfa%20cam%20spec_media-lin.png)
