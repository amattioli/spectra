# %% [markdown]
# # Iota [Herculis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1Zbb8ajyscfAEh8CbjBB1RFox_GWPo8n4eXwMTi72_Ac/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=iota+her&submit=SIMBAD+search): B3IV

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [06/06/2025](../../Osservazioni/20250606/Iota_her.html)
