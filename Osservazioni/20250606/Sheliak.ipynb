# %% [markdown]
# # [Sheliak - Beta Lyrae](../../Costellazioni/Lyra/Sheliak.html) del [06/06/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=40.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-06-06T21:21:03.0160315Z
# - EndCapture=2025-06-06T21:41:19.6212207Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_sheliak_20250606_890.png](attachment:_sheliak_20250606_890.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_sheliak_20250606_890-rect.png](attachment:_sheliak_20250606_890-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-370-400.png](attachment:_sheliak_20250606_890-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-400-430.png](attachment:_sheliak_20250606_890-rect-400-430.png)

# %% [markdown]
# ### Zoom 430 - 460 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-430-460.png](attachment:_sheliak_20250606_890-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 490 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-460-490.png](attachment:_sheliak_20250606_890-rect-460-490.png)

# %% [markdown]
# ### Zoom  490 - 520 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-490-520.png](attachment:_sheliak_20250606_890-rect-490-520.png)

# %% [markdown]
# ### Zoom  520 - 550 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-520-550.png](attachment:_sheliak_20250606_890-rect-520-550.png)

# %% [markdown]
# ### Zoom  550 - 580 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-550-580.png](attachment:_sheliak_20250606_890-rect-550-580.png)

# %% [markdown]
# ### Zoom  580 - 620 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-580-620.png](attachment:_sheliak_20250606_890-rect-580-620.png)

# %% [markdown]
# ### Zoom  620 - 670 nm

# %% [markdown]
# ![_sheliak_20250606_890-rect-620-670.png](attachment:_sheliak_20250606_890-rect-620-670.png)
