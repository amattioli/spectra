# %% [markdown]
# # [Beta Camelopardalis](../../Costellazioni/Camelopardalis/Beta_Cam.html) del [26/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=60.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-05-26T20:25:05.4893041Z
# - EndCapture=2024-05-26T20:35:11.0488372Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![2024-05-26-2030_6-beta%20cam%20spec_media-raw.png](attachment:2024-05-26-2030_6-beta%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# ![2024-05-26-2030_6-beta%20cam%20spec_media-resp-corr-self.png](attachment:2024-05-26-2030_6-beta%20cam%20spec_media-resp-corr-self.png)
