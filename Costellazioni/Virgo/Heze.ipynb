# %% [markdown]
# # Heze - Zeta [Virginis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1u1aKgxIHNyOA2rC-qquJcZeFA2hl6ea_1ahewh6BNZE/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=heze&submit=SIMBAD+search): A2Van

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [24/05/2025](../../Osservazioni/20250524/Heze.html)
