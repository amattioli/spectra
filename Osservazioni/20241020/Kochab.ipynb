# %% [markdown]
# # [Kochab - Beta Ursae Minoris](../../Costellazioni/Ursa_Minor/Kochab.html) del [20/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=25.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-20T20:07:21.5067694Z
# - EndCapture=2024-10-20T20:15:54.1173848Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00008.png](attachment:frame_00008.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00008-rect.png](attachment:frame_00008-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![frame_00008-rect-400-500.png](attachment:frame_00008-rect-400-500.png)

# %% [markdown]
# ### Zoom 500 - 600 nm

# %% [markdown]
# ![frame_00008-rect-500-600.png](attachment:frame_00008-rect-500-600.png)
