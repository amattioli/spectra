# %% [markdown]
# # [Segin - Epsilon Cassiopeiae](../../Costellazioni/Cassiopeia/Segin.html) del [31/03/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=102
# - Exposure=60.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-03-31T19:03:48.6801325Z
# - EndCapture=2025-03-31T19:54:19.6443963Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 50 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_segin_20250331_794.png](attachment:_segin_20250331_794.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_segin_20250331_794-rect.png](attachment:_segin_20250331_794-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_segin_20250331_794-rect-370-400.png](attachment:_segin_20250331_794-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_segin_20250331_794-rect-400-430.png](attachment:_segin_20250331_794-rect-400-430.png)

# %% [markdown]
# ### Zoom  430 - 460 nm

# %% [markdown]
# ![_segin_20250331_794-rect-430-460.png](attachment:_segin_20250331_794-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 490 nm

# %% [markdown]
# ![_segin_20250331_794-rect-460-490.png](attachment:_segin_20250331_794-rect-460-490.png)

# %% [markdown]
# ### Zoom  520 - 580 nm

# %% [markdown]
# ![_segin_20250331_794-rect-520-580.png](attachment:_segin_20250331_794-rect-520-580.png)

# %% [markdown]
# ### Zoom  580 - 670 nm

# %% [markdown]
# ![_segin_20250331_794-rect-580-670.png](attachment:_segin_20250331_794-rect-580-670.png)
