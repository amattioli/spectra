# %% [markdown]
# # [RY Dra](../../Costellazioni/Draco/RY_Dra.html) del [09/10/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=120.000s
# - Brightness=2
# - Temperature=-10
# - StartCapture=2025-10-09T19:31:10.8635471Z
# - EndCapture=2025-10-09T20:11:22.1252746Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 20 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_rydra_20251009_813.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (4250, 7500), flux_range=(0.0,1.75))

# %%
wavelength, flux = raw_wavelength, raw_flux
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 4000, 4250):.1f}")
# Out:
# SNR Reale stimato: 11.1

# %%
spectral_lines_summary = pd.read_csv('RY Dra spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('RY Dra spec - 2025-10-09.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (4250,7500), (0,1.85))

# %% [markdown]
# ### Zoom  440 - 470 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4380,4720), (0.0,0.12))

# %% [markdown]
# ### Zoom  470 - 510 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4680,5120), (0.00,0.8))

# %% [markdown]
# ### Zoom 510 - 560 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5080,5620), (0.0,1.60))

# %% [markdown]
# ### Zoom  560 - 610 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5580,6120), (0.0,1.70))

# %% [markdown]
# ### Zoom  610 - 660 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (6080,6620), (0.0,1.70))

# %% [markdown]
# ### Zoom  660 - 730 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (6580,7320), (0.0,1.70))
