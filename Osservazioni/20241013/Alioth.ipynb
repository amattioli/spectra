# %% [markdown]
# # [Alioth - Epsilon Ursae Majoris](../../Costellazioni/Ursa_Major/Alioth.html) del [13/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-0.3
# - StartCapture=2024-10-13T17:49:28.0527196Z
# - EndCapture=2024-10-13T17:52:33.2770569Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00002.png](attachment:frame_00002.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00002-rect.png](attachment:frame_00002-rect.png)

# %% [markdown]
# ### Zoom  390 - 540 nm

# %% [markdown]
# ![frame_00002-rect-390-540.png](attachment:frame_00002-rect-390-540.png)
