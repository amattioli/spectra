# %% [markdown]
# # [Albireo 1 - Beta 01 Cygni](../../Costellazioni/Cygnus/Albireo_1.html) del [31/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=50.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-31T19:12:54.8505881Z
# - EndCapture=2024-10-31T19:29:45.9247696Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 20 immagini

# %% [markdown]
# ![pp_lights_stacked-raw.png](attachment:pp_lights_stacked-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Altair della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-altair.png](attachment:pp_lights_stacked-resp-corr-altair.png)

# %% [markdown]
# Per riprodurre correttamente lo spettro, soprattutto nel blu/violetto, occorre effettuare la somma pesata di due spettri di riferimento: K3II e B9.5V. Qui di seguito i pesi sono stati determinati in modo empirico.

# %% [markdown]
# ![pp_lights_stacked-resp-corr-altair-two-ref.png](attachment:pp_lights_stacked-resp-corr-altair-two-ref.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-500.png](attachment:pp_lights_stacked-rect-400-500.png)

# %% [markdown]
# ### Zoom 500 - 600 nm

# %% [markdown]
# ![pp_lights_stacked-rect-500-600.png](attachment:pp_lights_stacked-rect-500-600.png)
