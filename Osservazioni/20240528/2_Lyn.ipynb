# %% [markdown]
# # [2 Lyncis](../../Costellazioni/Lynx/2_Lyn.html) del [28/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-0.1
# - StartCapture=2024-05-28T20:47:19.5164919Z
# - EndCapture=2024-05-28T21:04:49.0291383Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![2024-05-28-2100_7-2%20lyn%20spec_media.png](attachment:2024-05-28-2100_7-2%20lyn%20spec_media.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![2024-05-28-2100_7-2%20lyn%20spec_media-resp-corr-self.png](attachment:2024-05-28-2100_7-2%20lyn%20spec_media-resp-corr-self.png)
