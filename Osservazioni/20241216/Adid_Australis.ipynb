# %% [markdown]
# # [Adid Australis - Epsilon Persei](../../Costellazioni/Perseus/Adid_Australis.html) del [16/12/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=20.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-12-16T18:49:59.3218558Z
# - EndCapture=2024-12-16T18:56:51.2129712Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 20 immagini. Applicati bias, dark e flats. Elaborazione tramite ISIS

# %% [markdown]
# ![_epsper_20241216_789.png](attachment:_epsper_20241216_789.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![_epsper_20241216_789-resp-corr-self.png](attachment:_epsper_20241216_789-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_epsper_20241216_789-rect.png](attachment:_epsper_20241216_789-rect.png)

# %% [markdown]
# ### Zoom  370 - 410 nm

# %% [markdown]
# ![_epsper_20241216_789-rect-370-410.png](attachment:_epsper_20241216_789-rect-370-410.png)

# %% [markdown]
# ### Zoom  410 - 470 nm

# %% [markdown]
# ![_epsper_20241216_789-rect-410-470.png](attachment:_epsper_20241216_789-rect-410-470.png)

# %% [markdown]
# ### Zoom  560 - 600 nm

# %% [markdown]
# ![_epsper_20241216_789-rect-560-600.png](attachment:_epsper_20241216_789-rect-560-600.png)
