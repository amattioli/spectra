# %% [markdown]
# # [Caph - Beta Cassiopeiae](../../Costellazioni/Cassiopeia/Caph.html) del [29/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=35.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-11-29T16:56:56.3416214Z
# - EndCapture=2024-11-29T17:08:50.3247063Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 20 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Segin della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-segin.png](attachment:pp_lights_stacked-resp-corr-segin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  410 - 520 nm

# %% [markdown]
# ![pp_lights_stacked-rect-410-520.png](attachment:pp_lights_stacked-rect-410-520.png)
