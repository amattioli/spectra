# %% [markdown]
# # Orion

# %% [markdown]
# - [Betelgeuse - Alpha Ori](Betelgeuse.html)
# - [Mintaka - Delta Ori](Mintaka.html)
# - [Alnilam - Epsilon Ori](Alnilam.html)
# - [Alnitak - Zeta Ori](Alnitak.html)
# - [Meissa - Lambda Ori](Meissa.html)

# %% [markdown]
# ### Confronto tra le stelle della cintura

# %% [markdown]
# ![Orion%20Belt.png](attachment:Orion%20Belt.png)
