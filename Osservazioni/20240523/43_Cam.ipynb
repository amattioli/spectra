# %% [markdown]
# # [43 Cam](../../Costellazioni/Camelopardalis/43_Cam.html) del [23/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-5.1
# - StartCapture=2024-05-23T20:40:20.5632325Z
# - EndCapture=2024-05-23T21:06:16.4780838Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 8 immagini

# %% [markdown]
# ![2024-05-23-2053_4-43%20cam%20spec_mean-raw.png](attachment:2024-05-23-2053_4-43%20cam%20spec_mean-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# ![2024-05-23-2053_4-43%20cam%20spec_mean-resp-corr-self.png](attachment:2024-05-23-2053_4-43%20cam%20spec_mean-resp-corr-self.png)
