# %% [markdown]
# # [Kochab - Beta Ursae Minoris](../../Costellazioni/Ursa_Minor/Kochab.html) del [13/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=50
# - Exposure=25.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-13T19:23:33.2058162Z
# - EndCapture=2024-10-13T19:30:48.3779426Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00012.png](attachment:frame_00012.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00012-rect.png](attachment:frame_00012-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![frame_00012-rect-400-500.png](attachment:frame_00012-rect-400-500.png)

# %% [markdown]
# ### Zoom 500 - 600 nm

# %% [markdown]
# ![frame_00012-rect-500-600.png](attachment:frame_00012-rect-500-600.png)
