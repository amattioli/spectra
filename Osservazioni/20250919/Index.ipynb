# %% [markdown]
# # Osservazioni del 19/09/2025

# %% [markdown]
# ## Setup

# %% [markdown]
# - Ottica: Celestron C8
# - Montatura: iOptron CEM70
# - Camera: ZWO ASI533MM Pro
# - Guida: Alpy 600 guide module + ASI585MC
# - Spettroscopio: Alpy 600 con fenditura da 10$\mu$m + modulo di calibrazione
# - Luogo: Terrazzo Lato Cominio

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [Lambda Cas](Lambda_Cas.html)
# - [Nu Cas](Nu_Cas.html)
# - [Sigma Cas](Sigma_Cas.html)
# - [Xi Cas](Xi_Cas.html)
