# %% [markdown]
# # [2 Lyncis](../../Costellazioni/Lynx/2_Lyn.html) del [17/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=25.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-17T20:10:42.9621641Z
# - EndCapture=2024-06-17T20:23:30.8296605Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 7 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil-resp-corr-self.png](attachment:meanprofil-resp-corr-self.png)
