# %% [markdown]
# # [Albireo 2 - Beta 02 Cygni](../../Costellazioni/Cygnus/Albireo_2.html) del [31/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=60.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-31T18:46:30.3425049Z
# - EndCapture=2024-10-31T19:06:41.2169529Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 20 immagini

# %% [markdown]
# ![pp_lights_stacked-raw.png](attachment:pp_lights_stacked-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Altair della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-altair.png](attachment:pp_lights_stacked-resp-corr-altair.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 510 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-510.png](attachment:pp_lights_stacked-rect-400-510.png)
