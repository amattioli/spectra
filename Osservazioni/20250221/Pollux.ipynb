# %% [markdown]
# # [Pollux - Beta Geminorum](../../Costellazioni/Gemini/Pollux.html) del [21/02/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=12.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-02-21T18:28:30.0679148Z
# - EndCapture=2025-02-21T18:39:01.7611139Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 49 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_pollux_20250221_771.png](attachment:_pollux_20250221_771.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_pollux_20250221_771-rect.png](attachment:_pollux_20250221_771-rect.png)

# %% [markdown]
# ### Zoom  370 - 420 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-370-420.png](attachment:_pollux_20250221_771-rect-370-420.png)

# %% [markdown]
# ### Zoom  420 - 450 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-420-450.png](attachment:_pollux_20250221_771-rect-420-450.png)

# %% [markdown]
# ### Zoom  450 - 480 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-450-480.png](attachment:_pollux_20250221_771-rect-450-480.png)

# %% [markdown]
# ### Zoom  480 - 510 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-480-510.png](attachment:_pollux_20250221_771-rect-480-510.png)

# %% [markdown]
# ### Zoom  510 - 540 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-510-540.png](attachment:_pollux_20250221_771-rect-510-540.png)

# %% [markdown]
# ### Zoom  540 - 580 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-540-580.png](attachment:_pollux_20250221_771-rect-540-580.png)

# %% [markdown]
# ### Zoom  580 - 620 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-580-620.png](attachment:_pollux_20250221_771-rect-580-620.png)

# %% [markdown]
# ### Zoom  620 - 680 nm

# %% [markdown]
# ![_pollux_20250221_771-rect-620-680.png](attachment:_pollux_20250221_771-rect-620-680.png)
