# %% [markdown]
# # [Alkaid - Eta Ursae Majoris](../../Costellazioni/Ursa_Major/Alkaid.html) del [08/08/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=120.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-08-08T20:58:37.9387040Z
# - EndCapture=2025-08-08T21:58:54.7233520Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_alkaid_20250808_874.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,30.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_alkaid_20250808_874-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6000, 6200):.1f}")
# Out:
# SNR Reale stimato: 1195.5

# %%
spectral_lines_summary = pd.read_csv('Alkaid - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Alkaid - 2025-08-08.csv', usecols=[0, 1, 21], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6850), (0.45,1.3))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.4,1.3))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.4,1.3))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.6,1.2))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.7,1.2))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.7,1.2))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.7,1.2))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.6,1.2))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Alkaid - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)

df
# Out:
# amp = -8.219076312962896
# mu = 4102.079331703535
# sigma = 2.9061584415971216
# gamma = 4.466920215179841
# offset = 0.9988865702481841
# amp = -8.11741861543181
# mu = 4340.864801845447
# sigma = 3.1356764969456212
# gamma = 4.529787106695911
# offset = 0.9976900935345425
# amp = -7.7405456389215415
# mu = 4861.305094715708
# sigma = 3.2746142295853593
# gamma = 4.87766697596209
# offset = 0.9972910413506373
# amp = -8.355626190367131
# mu = 6563.845953994392
# sigma = 0.000244530886464701
# gamma = 8.743840244480621
# offset = 0.9955987399102217
# C:\Users\andrea\personal\physics\astro\spettroscopia\ipynb\Osservazioni\20250808\../../src\spectral_lines.py:57: RuntimeWarning: overflow encountered in multiply
#   return amp * voigt_profile(x - mean, sigma, gamma) + offset
# amp = -0.0615613022336607
# mu = 4009.440961507195
# sigma = 2.860606951684485
# offset = 1.0002744597281779
# amp = -0.17172091426976172
# mu = 4026.4681077140576
# sigma = 2.954319142772763
# offset = 1.0002744597281779
# amp = -0.08575108446475571
# mu = 4144.416357920156
# sigma = 2.777773428932076
# offset = 0.9990191950789977
# amp = -0.10254383222400403
# mu = 4388.589422483164
# sigma = 3.167169601357727
# offset = 0.9977612374253864
# amp = -0.14427807803049644
# mu = 4472.030058143772
# sigma = 4.2655566139192995
# offset = 0.9975861735273641
# amp = -0.037165153293166935
# mu = 4713.547482111875
# sigma = 2.7942001622193353
# offset = 0.9980825462432268
# amp = -0.09485453942323893
# mu = 4922.032945947381
# sigma = 3.2379427001377836
# offset = 0.9986248594229699
# amp = -0.05896546867586723
# mu = 6679.642209988274
# sigma = 3.3357081520084435
# offset = 1.001828404231231
# amp = -0.0271635297226107
# mu = 4268.150689075776
# sigma = 2.5267078222833286
# offset = 0.9976916253968682
#          Line   Lambda min   Lambda fit        EW    EW_Err       FWHM  \
# 0      Hdelta  4101.267242  4102.079332  8.228238  0.039102  12.783579
# 1      Hgamma  4340.745731  4340.864802  8.136213  0.044965  13.346213
# 2       Hbeta  4861.123441  4861.305095  7.761571  0.035833  14.163640
# 3       Halfa  6564.134482  6563.845954  8.392564  0.034824  17.487734
# 4   He I 4009  4008.903769  4009.440962  0.441303  0.009464   6.736729
# 5   He I 4026  4026.043383  4026.468108  1.271310  0.013703   6.957422
# 6   He I 4144  4144.592376  4144.416358  0.597658  0.012664   6.541656
# 7   He I 4388  4388.831869  4388.589422  0.815914  0.013765   7.458684
# 8   He I 4471  4471.197234  4472.030058  1.546378  0.021565  10.045386
# 9   He I 4713  4713.532324  4713.547482  0.260806  0.013081   6.580341
# 10  He I 4922  4922.064289  4922.032946  0.770930  0.013568   7.625355
# 11  He I 6678  6679.826873  6679.642210  0.492133  0.013845   7.855593
# 12  C II 4267  4267.426273  4268.150689  0.172439  0.010998   5.950397
#
#     FWHM_Err
# 0   0.050664
# 1   0.061856
# 2   0.072362
# 3   0.087481
# 4   0.150031
# 5   0.077541
# 6   0.106053
# 7   0.131525
# 8   0.205664
# 9   0.334050
# 10  0.150956
# 11  0.214184
# 12  0.318244
