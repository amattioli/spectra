# %% [markdown]
# # Theta [Ophiuchi](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1Fr0xk9xyQtVlhNaIAqpIB8LXzAkKhMTCWNJlGSARv0M/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# - Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=zeta+oph&submit=SIMBAD+search): OB
# - Classificazione [Bright Star Catalog](https://vizier.cds.unistra.fr/viz-bin/VizieR-S?HR%20%206453): B2IV

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [30/08/2025](../../Osservazioni/20250830/Theta_Oph.html)
