# %% [markdown]
# # [Castor - Alpha Gem](../../Costellazioni/Gemini/Castor.html) del [21/02/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=13.000s
# - Brightness=5
# - Temperature=-9.7
# - StartCapture=2025-02-21T18:12:46.2068411Z
# - EndCapture=2025-02-21T18:24:04.9377212Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 49 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_castor_20250221_759.png](attachment:_castor_20250221_759.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_castor_20250221_759-rect.png](attachment:_castor_20250221_759-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_castor_20250221_759-rect-370-400.png](attachment:_castor_20250221_759-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_castor_20250221_759-rect-400-430.png](attachment:_castor_20250221_759-rect-400-430.png)

# %% [markdown]
# ### Zoom  430 - 460 nm

# %% [markdown]
# ![_castor_20250221_759-rect-430-460.png](attachment:_castor_20250221_759-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 500 nm

# %% [markdown]
# ![_castor_20250221_759-rect-460-500.png](attachment:_castor_20250221_759-rect-460-500.png)

# %% [markdown]
# ### Zoom  500 - 550 nm

# %% [markdown]
# ![_castor_20250221_759-rect-500-550.png](attachment:_castor_20250221_759-rect-500-550.png)

# %% [markdown]
# ### Zoom  550 - 670 nm

# %% [markdown]
# ![_castor_20250221_759-rect-550-670.png](attachment:_castor_20250221_759-rect-550-670.png)
