# %% [markdown]
# # [Kappa Draconis](../../Costellazioni/Draco/Kappa.html) del [13/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=125
# - Exposure=60.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-13T20:12:07.0814062Z
# - EndCapture=2024-10-13T20:22:12.5490709Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00010.png](attachment:frame_00010.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![frame_00010-resp-corr-self.png](attachment:frame_00010-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00010-rect.png](attachment:frame_00010-rect.png)

# %% [markdown]
# ### Zoom  390 - 480 nm

# %% [markdown]
# ![frame_00010-rect-390-480.png](attachment:frame_00010-rect-390-480.png)
