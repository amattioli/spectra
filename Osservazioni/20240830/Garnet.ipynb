# %% [markdown]
# # [Garnet Star - Mu Cephei](../../Costellazioni/Cepheus/Garnet.html) del [30/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=30.000s
# - Brightness=5
# - Temperature=-0.1
# - StartCapture=2024-08-30T20:25:30.9617452Z
# - EndCapture=2024-08-30T21:16:25.7375517Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 15 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Alderamin della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-alderamin.png](attachment:meanprofil-resp-corr-alderamin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)

# %% [markdown]
# ### Zoom  430 - 530 nm

# %% [markdown]
# ![meanprofil-rect-430-530.png](attachment:meanprofil-rect-430-530.png)

# %% [markdown]
# ### Zoom  530 - 630 nm

# %% [markdown]
# ![meanprofil-rect-530-630.png](attachment:meanprofil-rect-530-630.png)
