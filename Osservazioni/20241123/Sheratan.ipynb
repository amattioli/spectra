# %% [markdown]
# # [Sheratan - Beta Arietis](../../Costellazioni/Aries/Sheratan.html) del [23/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=45.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-11-23T17:52:35.2716143Z
# - EndCapture=2024-11-23T18:03:58.8076540Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 7 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![pp_lights_stacked-resp-corr-self.png](attachment:pp_lights_stacked-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 530 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-530.png](attachment:pp_lights_stacked-rect-400-530.png)
