# %% [markdown]
# # [36 Ursae Majoris](../../Costellazioni/Ursa_Major/36_UMa.html) del [12/07/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=20.000s
# - Brightness=5
# - Temperature=4.8
# - StartCapture=2024-07-12T21:09:38.5930094Z
# - EndCapture=2024-07-12T21:43:56.7160485Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Merak della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-merak.png](attachment:meanprofil-resp-corr-merak.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)
