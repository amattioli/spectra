# %% [markdown]
# # [Merak - Beta Ursae Majoris](../../Costellazioni/Ursa_Major/Merak.html) del [12/07/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=50
# - Exposure=20.000s
# - Brightness=5
# - Temperature=5
# - StartCapture=2024-07-12T21:50:48.9443810Z
# - EndCapture=2024-07-12T22:25:08.1650828Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 6 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil-resp-corr-self.png](attachment:meanprofil-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)
