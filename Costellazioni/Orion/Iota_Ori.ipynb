# %% [markdown]
# # Iota [Orionis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1xU_xAUTUChZxHjkz4FmPBwAcMIQTuy4JRsK_OXxz-Do/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=iota+ori&submit=SIMBAD+search): O9IIIvar

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [06/03/2025](../../Osservazioni/20250306/Iota_Ori.html)
