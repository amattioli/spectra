# %% [markdown]
# # [Pherkad - Gamma Ursae Minoris](../../Costellazioni/Ursa_Minor/Pherkad.html) del [13/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=50
# - Exposure=25.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-13T19:41:04.1379670Z
# - EndCapture=2024-10-13T19:47:28.0748636Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00011.png](attachment:frame_00011.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di kappa draconis della stessa serata

# %% [markdown]
# ![frame_00011-resp-corr-kdra.png](attachment:frame_00011-resp-corr-kdra.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00011-rect.png](attachment:frame_00011-rect.png)

# %% [markdown]
# ### Zoom  400 - 480 nm

# %% [markdown]
# ![frame_00011-rect-400-480.png](attachment:frame_00011-rect-400-480.png)
