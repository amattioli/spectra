# %% [markdown]
# # [Muscida - Omicron Ursae Majoris](../../Costellazioni/Ursa_Major/Muscida.html) del [11/07/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=25.000s
# - Brightness=5
# - Temperature=5
# - StartCapture=2024-07-11T20:08:47.1642632Z
# - EndCapture=2024-07-11T20:30:06.5433235Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 6 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di h UMa della stessa serata

# %% [markdown]
# ![meanprofil.resp-corr-huma.png](attachment:meanprofil.resp-corr-huma.png)
