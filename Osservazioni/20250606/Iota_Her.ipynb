# %% [markdown]
# # [Iota Herculis](../../Costellazioni/Hercules/Iota_Her.html) del [06/06/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=30.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-06-06T20:35:41.0351712Z
# - EndCapture=2025-06-06T20:50:58.5837395Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_iota_her_20250606_858.png](attachment:_iota_her_20250606_858.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_iota_her_20250606_858-rect.png](attachment:_iota_her_20250606_858-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-370-400.png](attachment:_iota_her_20250606_858-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-400-430.png](attachment:_iota_her_20250606_858-rect-400-430.png)

# %% [markdown]
# ### Zoom 430 - 460 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-430-460.png](attachment:_iota_her_20250606_858-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 490 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-460-490.png](attachment:_iota_her_20250606_858-rect-460-490.png)

# %% [markdown]
# ### Zoom  490 - 540 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-490-540.png](attachment:_iota_her_20250606_858-rect-490-540.png)

# %% [markdown]
# ### Zoom  540 - 600 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-540-600.png](attachment:_iota_her_20250606_858-rect-540-600.png)

# %% [markdown]
# ### Zoom  600 - 670 nm

# %% [markdown]
# ![_iota_her_20250606_858-rect-600-670.png](attachment:_iota_her_20250606_858-rect-600-670.png)
