# %% [markdown]
# # [Altair - Alpha Aquilae](../../Costellazioni/Aquila/Altair.html) del [31/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=4.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-31T17:46:06.9983235Z
# - EndCapture=2024-10-31T17:53:45.8955673Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 100 immagini

# %% [markdown]
# ![pp_lights_stacked-raw.png](attachment:pp_lights_stacked-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![pp_lights_stacked-resp-corr-self.png](attachment:pp_lights_stacked-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  410 - 550 nm

# %% [markdown]
# ![pp_lights_stacked-rect-410-550.png](attachment:pp_lights_stacked-rect-410-550.png)
