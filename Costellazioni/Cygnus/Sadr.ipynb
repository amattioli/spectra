# %% [markdown]
# # Sadr - Gamma [Cygni](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/17EvRLA0eAvOh_Z3cIrPZzGKcurfRHNVQWl8bRLJ-er8/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=sadr&submit=SIMBAD+search): F8Ib

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [01/08/2025](../../Osservazioni/20250801/Sadr.html)
