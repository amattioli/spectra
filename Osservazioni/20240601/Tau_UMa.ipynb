# %% [markdown]
# # [Tau Ursa Majoris](../../Costellazioni/Ursa_Major/Tau_UMa.html) del [01/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=225
# - Exposure=20.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-01T22:04:39.8476942Z
# - EndCapture=2024-06-01T22:38:59.8217065Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![2024-06-01-2233_1-tau%20uma%20spec_media-raw.png](attachment:2024-06-01-2233_1-tau%20uma%20spec_media-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di 2 Lyn della stessa serata

# %% [markdown]
# ![2024-06-01-2233_1-tau%20uma%20spec_media-resp-corr-2lyn-3.png](attachment:2024-06-01-2233_1-tau%20uma%20spec_media-resp-corr-2lyn-3.png)
