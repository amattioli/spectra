# %% [markdown]
# # [BN Camelopardalis](../../Costellazioni/Camelopardalis/BN_Cam.html) del [10/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=25.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-05-10T22:08:26.1602089Z
# - EndCapture=2024-05-10T22:08:51.7700979Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 6 immagini

# %% [markdown]
# ![2024-05-10-2231_2-bn%20cam%20spec_mean-raw.png](attachment:2024-05-10-2231_2-bn%20cam%20spec_mean-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# ![2024-05-10-2231_2-bn%20cam%20spec_mean-resp-corr-self.png](attachment:2024-05-10-2231_2-bn%20cam%20spec_mean-resp-corr-self.png)
