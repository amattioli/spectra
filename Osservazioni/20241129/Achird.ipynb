# %% [markdown]
# # [Achird - Eta Cassiopeiae](../../Costellazioni/Cassiopeia/Achird.html) del [29/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=180.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-11-29T17:59:43.6546397Z
# - EndCapture=2024-11-29T18:29:49.4257363Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 10 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Segin della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-segin.png](attachment:pp_lights_stacked-resp-corr-segin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-500.png](attachment:pp_lights_stacked-rect-400-500.png)

# %% [markdown]
# ### Zoom  500 - 600 nm

# %% [markdown]
# ![pp_lights_stacked-rect-500-600.png](attachment:pp_lights_stacked-rect-500-600.png)
