# %% [markdown]
# # [Beta Camelopardalis](../../Costellazioni/Camelopardalis/Beta_Cam.html) del [10/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=25.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-05-10T20:17:35.9068421Z
# - EndCapture=2024-05-10T21:00:15.8745004Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 4 immagini

# %% [markdown]
# ![2024-05-10-2039_1-beta%20cam%20spec_media-raw.png](attachment:2024-05-10-2039_1-beta%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# ![2024-05-10-2039_1-beta%20cam%20spec_media-resp-corr-self.png](attachment:2024-05-10-2039_1-beta%20cam%20spec_media-resp-corr-self.png)
