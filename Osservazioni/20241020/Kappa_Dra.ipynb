# %% [markdown]
# # [Kappa Draconis](../../Costellazioni/Draco/Kappa_Dra.html) del [20/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=60.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-20T20:22:44.8282576Z
# - EndCapture=2024-10-20T20:32:50.4942833Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![frame_00007.png](attachment:frame_00007.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00007-rect.png](attachment:frame_00007-rect.png)

# %% [markdown]
# ### Zoom  390 - 480 nm

# %% [markdown]
# ![frame_00007-rect-390-480.png](attachment:frame_00007-rect-390-480.png)
