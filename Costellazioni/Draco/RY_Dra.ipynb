# %% [markdown]
# # RY [Draconis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1mRxyReiqjkewy5fkCgSe2EQVv1zxOeY83fLY-_B4m4M/edit?gid=1230761685#gid=1230761685)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=ry+dra&submit=SIMBAD+search): C-N3III

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [09/10/2025](../../Osservazioni/20251009/RY_Dra.html)
