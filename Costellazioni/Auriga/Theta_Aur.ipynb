# %% [markdown]
# # Theta [Aurigae](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Sono ben visibili le righe del silicio $\lambda$3856 e $\lambda$3863 che caratterizzano la classe A peculiare Silicio.

# %% [markdown]
# Classificazione  [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=theta+aur&submit=SIMBAD+search): A0VpSi

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [29/01/2025](../../Osservazioni/20250129/Theta_Aur.html)
