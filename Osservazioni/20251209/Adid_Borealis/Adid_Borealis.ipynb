# %% [markdown]
# # [Adid Borealis - Delta Persei](../../../Costellazioni/Perseus/Adid_Borealis.html) del [09/12/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=60.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-12-09T17:39:23.9338022Z
# - EndCapture=2025-12-09T18:09:41.3991337Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 28 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_adidborealis_20251209_755.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,20.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_adidborealis_20251209_755-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5720, 5820):.1f}")
# Out:
# SNR Reale stimato: 1050.1

# %%
spectral_lines_summary = pd.read_csv('Adid Borealis spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Adid Borealis spec - 2025-12-09.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.50,1.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.60,1.20))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.60,1.20))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.60,1.20))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.60,1.20))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.60,1.20))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.60,1.20))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Adid Borealis spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)
df = df.sort_values('Lambda fit')
df
# Out:
# fwhm_use =  12.97128194999641
# amp = -8.04329686673675
# mu = 4102.037387729702
# sigma = 1.1726933994994286
# gamma = 5.5033955154756145
# offset = 0.9928072138382462
# fwhm_use =  12.010446249996676
# amp = -6.964389854250356
# mu = 4340.793882326615
# sigma = 2.7512926514398663
# gamma = 4.168742474486987
# offset = 0.9984031624816605
# fwhm_use =  12.97128194999641
# amp = -6.264288322688084
# mu = 4861.216941277624
# sigma = 3.137386948742316
# gamma = 3.975418703131459
# offset = 1.0018784455589531
# fwhm_use =  14.892953349995878
# amp = -5.620085205998649
# mu = 6562.745804985199
# sigma = 2.1292495117562056
# gamma = 6.191507672601828
# offset = 1.0045372428384878
# fwhm_use =  7.2062677499980055
# amp = -0.040564328318608504
# mu = 4009.40718440245
# sigma = 2.812740643606334
# offset = 0.9989345374774207
# fwhm_use =  7.6866855999978725
# amp = -0.09301382899357397
# mu = 4026.3771891440956
# sigma = 2.9722176898566355
# offset = 0.9989345374774207
# ...
