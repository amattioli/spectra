# %% [markdown]
# # [HR8023 in Cygnus](../../Costellazioni/Cygnus/HR8023.html) del [18/07/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
wavelength, flux = spec.load("_hr8023_20250718_936-rect.fit")
flux = spec.cleanup_flux(flux)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=150.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-07-18T22:27:45.8128094Z
# - EndCapture=2025-07-18T22:52:51.8105832Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_hr8023_20250718_936.png](attachment:_hr8023_20250718_936.png)

# %% [markdown]
# ## Rectified Spectrum [download](_hr8023_20250718_936-rect.fit)

# %%
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5200, 5300):.1f}")
# Out:
# SNR Reale stimato: 719.4

# %% [markdown]
# ![_hr8023_20250718_936-rect.png](attachment:_hr8023_20250718_936-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_hr8023_20250718_936-rect-370-400.png](attachment:_hr8023_20250718_936-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_hr8023_20250718_936-rect-400-430.png](attachment:_hr8023_20250718_936-rect-400-430.png)

# %% [markdown]
# ### Zoom 430 - 460 nm

# %% [markdown]
# ![_hr8023_20250718_936-rect-430-460.png](attachment:_hr8023_20250718_936-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 490 nm

# %% [markdown]
# ![_hr8023_20250718_936-rect-460-490.png](attachment:_hr8023_20250718_936-rect-460-490.png)

# %% [markdown]
# ### Zoom  490 - 580 nm

# %% [markdown]
# ![_hr8023_20250718_936-rect-490-580.png](attachment:_hr8023_20250718_936-rect-490-580.png)

# %% [markdown]
# ### Zoom  580 - 670 nm

# %% [markdown]
# ![_hr8023_20250718_936-rect-580-670.png](attachment:_hr8023_20250718_936-rect-580-670.png)
