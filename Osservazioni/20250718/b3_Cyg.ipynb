# %% [markdown]
# # [b3 Cygni](../../Costellazioni/Cygnus/b3_Cyg.html) del [18/07/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
wavelength, flux = spec.load("_b3cyg_20250718_886-rect.fit")
flux = spec.cleanup_flux(flux)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=40.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-07-18T21:16:14.4190898Z
# - EndCapture=2025-07-18T21:26:22.7446982Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 15 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_b3cyg_20250718_886.png](attachment:_b3cyg_20250718_886.png)

# %% [markdown]
# ## Rectified Spectrum [download](_b3cyg_20250718_886-rect.fit)

# %%
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 5500, 5600):.1f}")
# Out:
# SNR Reale stimato: 423.4

# %% [markdown]
# ![_b3cyg_20250718_886-rect.png](attachment:_b3cyg_20250718_886-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-370-400.png](attachment:_b3cyg_20250718_886-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-400-430.png](attachment:_b3cyg_20250718_886-rect-400-430.png)

# %% [markdown]
# ### Zoom 430 - 460 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-430-460.png](attachment:_b3cyg_20250718_886-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 490 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-460-490.png](attachment:_b3cyg_20250718_886-rect-460-490.png)

# %% [markdown]
# ### Zoom  490 - 520 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-490-520.png](attachment:_b3cyg_20250718_886-rect-490-520.png)

# %% [markdown]
# ### Zoom  520 - 570 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-520-570.png](attachment:_b3cyg_20250718_886-rect-520-570.png)

# %% [markdown]
# ### Zoom  570 - 670 nm

# %% [markdown]
# ![_b3cyg_20250718_886-rect-570-670.png](attachment:_b3cyg_20250718_886-rect-570-670.png)
