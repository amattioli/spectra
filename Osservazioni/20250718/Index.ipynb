# %% [markdown]
# # Osservazioni del 18/07/2025

# %% [markdown]
# ## Setup

# %% [markdown]
# - Ottica: Celestron C8
# - Montatura: iOptron CEM70
# - Camera: ZWO ASI533MM Pro
# - Guida: Alpy 600 guide module + ASI585MC
# - Spettroscopio: Alpy 600 con fenditura da 10$\mu$m + modulo di calibrazione
# - Luogo: Terrazzo Lato Cominio

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [b3 Cyg](b3_Cyg.html)
# - [Chi Cyg](Chi_Cyg.html)
# - [V1770 Cyg](V1770_Cyg.html)
# - [HR8023](HR8023.html)
