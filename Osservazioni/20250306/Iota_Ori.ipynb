# %% [markdown]
# # [Iota Orionis](../../Costellazioni/Orion/Iota_Ori.html) del [06/03/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=101
# - Exposure=50.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-03-06T19:16:44.3528519Z
# - EndCapture=2025-03-06T19:50:28.2682402Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 40 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_iota_ori_20250306_803.png](attachment:_iota_ori_20250306_803.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_iota_ori_20250306_803-rect.png](attachment:_iota_ori_20250306_803-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_iota_ori_20250306_803-rect-370-400.png](attachment:_iota_ori_20250306_803-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_iota_ori_20250306_803-rect-400-430.png](attachment:_iota_ori_20250306_803-rect-400-430.png)

# %% [markdown]
# ### Zoom  430 - 460 nm

# %% [markdown]
# ![_iota_ori_20250306_803-rect-430-460.png](attachment:_iota_ori_20250306_803-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 510 nm

# %% [markdown]
# ![_iota_ori_20250306_803-rect-460-510.png](attachment:_iota_ori_20250306_803-rect-460-510.png)

# %% [markdown]
# ### Zoom  510 - 580 nm

# %% [markdown]
# ![_iota_ori_20250306_803-rect-510-580.png](attachment:_iota_ori_20250306_803-rect-510-580.png)

# %% [markdown]
# ### Zoom  580 - 670 nm

# %% [markdown]
# ![_iota_ori_20250306_803-rect-580-670.png](attachment:_iota_ori_20250306_803-rect-580-670.png)
