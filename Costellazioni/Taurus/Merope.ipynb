# %% [markdown]
# # Merope - 23 [Tauri](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1alo_yz6lZRGUYC7_y4FJcmd6RlY6P9h-p57ebV4EMvs/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=merope&submit=SIMBAD+search): B6IV(e)

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [03/03/2025](../../Osservazioni/20250303/Merope.html)
