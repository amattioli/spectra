# %% [markdown]
# # [Y Canum Venaticorum](../../Costellazioni/Canes_Venatici/Y_CVn.html) del [22/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=30.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-22T21:04:22.2932901Z
# - EndCapture=2024-06-22T21:55:17.6672626Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![2024-06-22-2127_2-y%20cvn%20spec_00045.png](attachment:2024-06-22-2127_2-y%20cvn%20spec_00045.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![2024-06-22-2127_2-y%20cvn%20spec_00045.resp-corr-corcaroli.png](attachment:2024-06-22-2127_2-y%20cvn%20spec_00045.resp-corr-corcaroli.png)

# %% [markdown]
# ## Zoom 470 - 540 nm

# %% [markdown]
# Sono evidenziate le bande del SiC$_2$ (Merryl-Sanford Bands)

# %% [markdown]
# ![2024-06-22-2127_2-y%20cvn%20spec_00045.resp-corr-corcaroli-zoom-merryl-sanford.png](attachment:2024-06-22-2127_2-y%20cvn%20spec_00045.resp-corr-corcaroli-zoom-merryl-sanford.png)
