# %% [markdown]
# # [Beta Delphini](../../../Costellazioni/Delphinus/Beta_Del.html) del [04/11/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-11-04T18:23:41.8214904Z
# - EndCapture=2025-11-04T18:31:28.9661792Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 29 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_betadel_20251104_771.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,12.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_betadel_20251104_771-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6695, 6785):.1f}")
# Out:
# SNR Reale stimato: 267.8

# %%
spectral_lines_summary = pd.read_csv('Beta Del spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Beta Del spec - 2025-11-04.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.50,1.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.60,1.20))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.60,1.20))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.60,1.20))

# %% [markdown]
# ### Zoom  490 - 520 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5220), (0.60,1.20))

# %% [markdown]
# ### Zoom  520 - 550 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5180,5520), (0.60,1.20))

# %% [markdown]
# ### Zoom  550 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5480,6020), (0.60,1.20))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.60,1.20))
