# %% [markdown]
# # [Alpha Lacertae](../../../Costellazioni/Lacerta/Alpha_Lac.html) del [12/12/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=20.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-12-12T17:18:09.2187585Z
# - EndCapture=2025-12-12T17:28:27.3915399Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 29 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_alphalac_20251212_725.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,32.0))

# %% [markdown]
# ## Rectified Spectrum

# %%
wavelength, flux = spec.load("_alphalac_20251212_725-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6730, 6830):.1f}")
# Out:
# SNR Reale stimato: 316.1

# %%
spectral_lines_summary = pd.read_csv('Alpha Lac spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Alpha Lac spec - 2025-12-12.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.40,1.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.60,1.20))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.60,1.20))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.60,1.20))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.60,1.20))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.60,1.20))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.60,1.20))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Alpha Lac spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)
df = df.sort_values('Lambda fit')
df
# Out:
# fwhm_use =  21.35053249998964
# amp = -21.234107772349763
# mu = 4101.471348156227
# sigma = 2.6314870946375137
# gamma = 9.44038679147578
# offset = 0.9966849175646563
# fwhm_use =  21.835771874989405
# amp = -19.806217655072377
# mu = 4340.426494096023
# sigma = 2.6964761334462137
# gamma = 9.322126890756772
# offset = 0.9841140308254422
# fwhm_use =  22.32101124998917
# amp = -18.989447726498387
# mu = 4861.295661578309
# sigma = 2.4523707057428976
# gamma = 10.019023128115066
# offset = 0.9916228380839782
# fwhm_use =  21.835771874988495
# amp = -14.878515296832456
# mu = 6562.461653481973
# sigma = 0.00012129097895329118
# gamma = 11.058330891192634
# offset = 0.9984389489975299
# C:\Users\andrea\personal\physics\astro\spettroscopia\ipynb\Osservazioni\20251212\Alpha_Lac\../../../src\spectral_lines.py:57: RuntimeWarning: overflow encountered in multiply
#   return amp * voigt_profile(x - mean, sigma, gamma) + offset
# fwhm_use =  7.278590624996468
# amp = -0.0185056319847788
# mu = 5055.415358413974
# sigma = 2.6115162159649272
# offset = 1.0016779222677603
# fwhm_use =  7.466009714704366
# amp = -0.026674722307973957
# mu = 6346.686673354174
# sigma = 2.814328756825743
# offset = 1.0046585998441822
# fwhm_use =  7.763829999996233
# amp = -0.02003145211560538
# mu = 6371.380829429532
# sigma = 3.4451422810397485
# offset = 1.0045796490487466
# amp = -0.07237518957086589
# mu = 4481.497895633991
# sigma = 2.2748007799931087
# offset = 1.0033526200341096
# amp = -0.01936311349920813
# mu = 4489.755277245635
# sigma = 2.10758365899112
# offset = 1.0033526200341096
# amp = -0.005578976564163206
# mu = 5032.191304033366
# sigma = 1.86628428726319
# offset = 1.0018547093508845
# amp = -0.013568539658007198
# mu = 5040.99945228565
# sigma = 2.7205275541101996
# offset = 1.0018547093508845
#             Line   Lambda min   Lambda fit         EW    EW_Err       FWHM  \
# 0      H$\delta$  4100.905669  4101.471348  21.304735  0.041773  20.846018
# 1      H$\gamma$  4340.613921  4340.426494  20.125938  0.050150  20.719466
# 7     Mg II 4481  4481.260000  4481.497896   0.411310  0.011612   5.357156
# 8     Fe II 4489  4489.000000  4489.755277   0.101952  0.007028   4.963360
# 2       H$\beta$  4861.275770  4861.295662  19.149869  0.070600  21.681356
# 9   Unknown 5031  5031.000000  5032.191304   0.026051  0.046178   4.395099
# 10    Si II 5041  5041.130000  5040.999452   0.092357  0.013361   6.406842
# 4     Si II 5056  5054.886281  5055.415358   0.120937  0.011984   6.150121
# 5     Si II 6347  6346.108257  6346.686673   0.187304  0.012298   6.627744
# 6     Si II 6371  6371.825944  6371.380829   0.172197  0.013780   8.113310
# 3      H$\alpha$  6562.039779  6562.461653  14.901778  0.036406  22.116729
#
#     FWHM_Err
# 0   0.061243
# 1   0.069404
# 7   0.164233
# 8   0.397874
# 2   0.096354
# 9   8.365319
# 10  0.889762
# 4   0.623664
# 5   0.455696
# 6   0.826930
# 3   0.064352
