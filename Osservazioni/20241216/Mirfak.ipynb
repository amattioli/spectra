# %% [markdown]
# # [Mirfak - Alpha Persei](../../Costellazioni/Perseus/Mirfak.html) del [16/12/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=90.000s
# - Brightness=0
# - Temperature=-10
# - StartCapture=2024-12-16T17:06:07.1137387Z
# - EndCapture=2024-12-16T17:21:12.8964969Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 10 immagini. Applicati bias, dark e flat. Elaborazione tramite ISIS

# %% [markdown]
# ![_mirfak_20241216_713.png](attachment:_mirfak_20241216_713.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![_mirfak_20241216_713-resp-corr-self.png](attachment:_mirfak_20241216_713-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_mirfak_20241216_713-rect.png](attachment:_mirfak_20241216_713-rect.png)

# %% [markdown]
# ### Zoom  400 - 470 nm

# %% [markdown]
# ![_mirfak_20241216_713-rect-400-470.png](attachment:_mirfak_20241216_713-rect-400-470.png)

# %% [markdown]
# ### Zoom  470 - 540 nm

# %% [markdown]
# ![_mirfak_20241216_713-rect-470-540.png](attachment:_mirfak_20241216_713-rect-470-540.png)

# %% [markdown]
# ### Zoom  540 - 610 nm

# %% [markdown]
# ![_mirfak_20241216_713-rect-540-610.png](attachment:_mirfak_20241216_713-rect-540-610.png)
