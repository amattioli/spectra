# %% [markdown]
# # Zeta [Ophiuchi](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1ML9a7ddWneR8hqcGjjB2oq9PL-ZRz5brVzA-xnTZh0w/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=zeta+oph&submit=SIMBAD+search): O9.2IVnn

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [28/06/2025](../../Osservazioni/20250628/Zeta_Oph.html)
