# %% [markdown]
# # Alzirr - Ksi [Geminorum](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1eG9lf3a4lwfgdJfh9XnWAqqU0Gx-D1_SSZe_rlWF1ro/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=alzirr&submit=SIMBAD+search): F5IV-V

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [06/02/2025](../../Osservazioni/20250206/Alzirr.html)
