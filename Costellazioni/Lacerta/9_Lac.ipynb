# %% [markdown]
# # 9 [Lacertae](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1CAwBAIwKPpiFcJcEAxnjAYct3HURJRadeMQCx2kjSss/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# - Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=9+lac&submit=SIMBAD+search): A9VkA7mA6
# - Classificazione [Bright Star Catalogue](https://vizier.cds.unistra.fr/viz-bin/VizieR-5?-ref=VIZ6a3c07f123ac1e&-out.add=.&-source=V/50/catalog&recno=8613): A8IV

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [12/09/2025](../../Osservazioni/20250912/9_Lac.html)
