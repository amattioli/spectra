# %% [markdown]
# # [Algenib - Gamma Pegasi](../../Costellazioni/Pegasus/Algenib.html) del [23/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=45.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-11-23T17:36:37.8476598Z
# - EndCapture=2024-11-23T17:48:01.5455749Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![pp_lights_00006.png](attachment:pp_lights_00006.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Sheratan della stessa serata

# %% [markdown]
# ![pp_lights_00006-resp-corr-sheratan.png](attachment:pp_lights_00006-resp-corr-sheratan.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_00006-rect.png](attachment:pp_lights_00006-rect.png)

# %% [markdown]
# ### Zoom  390 - 510 nm

# %% [markdown]
# ![pp_lights_00006-rect-390-510.png](attachment:pp_lights_00006-rect-390-510.png)
