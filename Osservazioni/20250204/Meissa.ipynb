# %% [markdown]
# # [Meissa - Lambda Orionis](../../Costellazioni/Orion/Meissa.html) del [04/02/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=101
# - Exposure=50.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-02-04T17:34:46.8969199Z
# - EndCapture=2025-02-04T18:01:45.6713996Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 32 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_meissa_20250204_732.png](attachment:_meissa_20250204_732.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Castor della stessa serata

# %% [markdown]
# ![_meissa_20250204_732-resp-corr-castor.png](attachment:_meissa_20250204_732-resp-corr-castor.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_meissa_20250204_732-rect.png](attachment:_meissa_20250204_732-rect.png)

# %% [markdown]
# ### Zoom  370 - 420 nm

# %% [markdown]
# ![_meissa_20250204_732-rect-370-420.png](attachment:_meissa_20250204_732-rect-370-420.png)

# %% [markdown]
# ### Zoom  420 - 470 nm

# %% [markdown]
# ![_meissa_20250204_732-rect-420-470.png](attachment:_meissa_20250204_732-rect-420-470.png)

# %% [markdown]
# ### Zoom  470 - 520 nm

# %% [markdown]
# ![_meissa_20250204_732-rect-470-520.png](attachment:_meissa_20250204_732-rect-470-520.png)

# %% [markdown]
# ### Zoom  520 - 600 nm

# %% [markdown]
# ![_meissa_20250204_732-rect-520-600.png](attachment:_meissa_20250204_732-rect-520-600.png)

# %% [markdown]
# ### Zoom  600 - 700 nm

# %% [markdown]
# ![_meissa_20250204_732-rect-600-710.png](attachment:_meissa_20250204_732-rect-600-710.png)
