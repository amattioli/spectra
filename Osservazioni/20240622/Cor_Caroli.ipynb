# %% [markdown]
# # [Cor Caroli - Alpha 2 Canum Venaticorum](../../Costellazioni/Canes_Venatici/Cor_Caroli.html) del [22/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=10.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-22T20:23:22.7822689Z
# - EndCapture=2024-06-22T20:41:04.5784310Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil.resp-corr-self.png](attachment:meanprofil.resp-corr-self.png)

# %% [markdown]
# ## Zoom 400 - 530 nm

# %% [markdown]
# Si notano bene le righe del Si I $\lambda$4128-31 e del Eu II $\lambda$4205 che rendono lo spettro peculiare

# %% [markdown]
# ![meanprofil.resp-corr-self-zoom.png](attachment:meanprofil.resp-corr-self-zoom.png)
