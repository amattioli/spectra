# %% [markdown]
# # [Beta Camelopardalis](../../Costellazioni/Camelopardalis/Beta_Cam.html) del [04/05/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-5.1
# - StartCapture=2024-05-04T20:12:23.4715422Z
# - EndCapture=2024-05-04T20:38:19.0380605Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 3 immagini

# %% [markdown]
# ![2024-05-04-2025_4-beta%20cam%20spec_media-raw.png](attachment:2024-05-04-2025_4-beta%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ![2024-05-04-2025_4-beta%20cam%20spec_media-lin.png](attachment:2024-05-04-2025_4-beta%20cam%20spec_media-lin.png)
