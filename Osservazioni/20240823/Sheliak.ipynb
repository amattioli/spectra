# %% [markdown]
# # [Sheliak - Beta Lyrae](../../Costellazioni/Lyra/Sheliak.html) del [23/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=194
# - Exposure=10.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-23T20:40:26.3607513Z
# - EndCapture=2024-08-23T20:58:08.5097484Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 9 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Vega della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-vega.png](attachment:meanprofil-resp-corr-vega.png)
