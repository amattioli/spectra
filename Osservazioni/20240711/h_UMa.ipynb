# %% [markdown]
# # [h Ursae Majoris](../../Costellazioni/Ursa_Major/h_UMa.html) del [11/07/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=140
# - Exposure=25.000s
# - Brightness=5
# - Temperature=5
# - StartCapture=2024-07-11T20:40:17.1774039Z
# - EndCapture=2024-07-11T21:22:57.5170886Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 15 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil.resp-corr-self.png](attachment:meanprofil.resp-corr-self.png)
