# %% [markdown]
# # Miram - Eta Persei 28/04/2024

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-04-28T20:43:05.4949158Z
# - EndCapture=2024-04-28T21:08:59.0856303Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Lo spettro seguente è stato ottenuto come media di 4 immagini

# %% [markdown]
# ![2024-04-28-2056_1-miram%20spec_media-raw.png](attachment:2024-04-28-2056_1-miram%20spec_media-raw.png)

# %% [markdown]
# ## Flux Calibrated Spectrum

# %% [markdown]
# Lo spettro seguente è stato ottenuto dividendo per la risposta ottenuta dallo spettro di Mirfak della stessa serata

# %% [markdown]
# ### Full Spectrum

# %% [markdown]
# ![2024-04-28-2056_1-miram%20spec_media-resp-corr-mirfak.png](attachment:2024-04-28-2056_1-miram%20spec_media-resp-corr-mirfak.png)

# %% [markdown]
# ### Zoom 420-510 nm

# %% [markdown]
# ![2024-04-28-2056_1-miram%20spec_media-resp-corr-mirfak-4200-5100.png](attachment:2024-04-28-2056_1-miram%20spec_media-resp-corr-mirfak-4200-5100.png)
