# %% [markdown]
# # Electra - 17 [Tauri](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1O20bGM1ApFUWO2YBpr9qoc7cZpT3nxAX9_gpWj3ofFc/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=electra&submit=SIMBAD+search): B6IIIe

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [03/03/2025](../../Osservazioni/20250303/Electra.html)
