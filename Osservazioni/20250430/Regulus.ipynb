# %% [markdown]
# # [Regulus - Alpha Leo](../../Costellazioni/Leo/Regulus.html) del [30/04/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=25.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-04-30T19:40:42.6808453Z
# - EndCapture=2025-04-30T20:02:01.0270021Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 34 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_regulus_20250430_820.png](attachment:_regulus_20250430_820.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_regulus_20250430_820-rect.png](attachment:_regulus_20250430_820-rect.png)

# %% [markdown]
# ### Zoom  370 - 400 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-370-400.png](attachment:_regulus_20250430_820-rect-370-400.png)

# %% [markdown]
# ### Zoom  400 - 430 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-400-430.png](attachment:_regulus_20250430_820-rect-400-430.png)

# %% [markdown]
# ### Zoom  430 - 460 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-430-460.png](attachment:_regulus_20250430_820-rect-430-460.png)

# %% [markdown]
# ### Zoom  460 - 510 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-460-510.png](attachment:_regulus_20250430_820-rect-460-510.png)

# %% [markdown]
# ### Zoom  510 - 560 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-510-560.png](attachment:_regulus_20250430_820-rect-510-560.png)

# %% [markdown]
# ### Zoom  560 - 610 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-560-610.png](attachment:_regulus_20250430_820-rect-560-610.png)

# %% [markdown]
# ### Zoom  610 - 670 nm

# %% [markdown]
# ![_regulus_20250430_820-rect-610-670.png](attachment:_regulus_20250430_820-rect-610-670.png)
