# %% [markdown]
# # Mirfak - Alpha Per

# %% [markdown]
# ## Descrizione

# %% [markdown]
# - Mv = 1.79 (Simbad)
# - Classe spettrale = F5Ib (Simbad)
# - Teff = 6370K (SkySafari 6)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Usando lo spettro del 16/12/20224:
# - Ca II H e K visibili
# - Ca II H/Hgamma > 1
# - Ca II K/H ~ 1
# - G Band visibile
#
# Dunque: F3-F9
#
# Classificazione Simbad: F5I

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [16/12/2024](../../Osservazioni/20241216/Mirfak.html)
