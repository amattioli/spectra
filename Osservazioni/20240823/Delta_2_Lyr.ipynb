# %% [markdown]
# # [Delta 2 Lyrae](../../Costellazioni/Lyra/Delta_2_Lyr.html) del [23/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=18.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-23T21:04:24.1615010Z
# - EndCapture=2024-08-23T21:35:17.6557811Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 9 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Vega della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-vega.png](attachment:meanprofil-resp-corr-vega.png)
