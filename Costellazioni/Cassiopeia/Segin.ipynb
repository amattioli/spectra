# %% [markdown]
# # Segin - Epsilon [Cassiopeiae](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1sILFv_IwpJIFieOzp5yB_E8Tv1zDwG_mcYJAJ2vaY3c/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=segin&submit=SIMBAD+search): B3Vp_sh

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [29/11/2024](../../Osservazioni/20241129/Segin.html)
# - [31/03/2025](../../Osservazioni/20250331/Segin.html)
