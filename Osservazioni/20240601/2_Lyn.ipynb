# %% [markdown]
# # [2 Lyncis](../../Costellazioni/Lynx/2_Lyn.html) del [01/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=225
# - Exposure=20.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-01T20:28:23.9460556Z
# - EndCapture=2024-06-01T21:02:42.6405327Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![2024-06-01-2054_8-2%20lyn%20spec_media-raw.png](attachment:2024-06-01-2054_8-2%20lyn%20spec_media-raw.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![2024-06-01-2054_8-2%20lyn%20spec_media-resp-corr-self3.png](attachment:2024-06-01-2054_8-2%20lyn%20spec_media-resp-corr-self3.png)
