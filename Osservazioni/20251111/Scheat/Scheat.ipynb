# %% [markdown]
# # [Scheat - Beta Pegasi](../../../Costellazioni/Pegasus/Scheat.html) del [11/11/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=30.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-11-11T18:09:34.2627610Z
# - EndCapture=2025-11-11T18:24:51.6267869Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 26 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_scheat_20251111_763.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,2.5))

# %% [markdown]
# ## Flux Corrected Spectrum

# %%
wavelength, flux = spec.load("_scheat_20251111_763-resp-corr.fit")
flux = spec.cleanup_flux(flux)

# %%
spectral_lines_summary = pd.read_csv('Scheat spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Scheat spec - 2025-11-11.csv', usecols=[0, 1, 13], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.0,2.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.0,0.25))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.00,0.5))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.0,1.00))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.0,1.20))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.0,1.50))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.00,1.70))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.00,2.05))

# %% [markdown]
# ### Zoom  670 - 740 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (6680,7420), (0.00,2.65))
