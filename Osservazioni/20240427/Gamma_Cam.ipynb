# %% [markdown]
# # Gamma Camelopardalis 27/04/2024

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-04-27T21:45:02.3868485Z
# - EndCapture=2024-04-27T22:10:58.3969317Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 4 immagini

# %% [markdown]
# ![2024-04-27-2158_1-gamma%20cam%20spec_media-raw.png](attachment:2024-04-27-2158_1-gamma%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ![2024-04-27-2158_1-gamma%20cam%20spec_media-lin.png](attachment:2024-04-27-2158_1-gamma%20cam%20spec_media-lin.png)
