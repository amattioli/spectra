# %% [markdown]
# # Lambda [Cassiopeiae](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1-4n5HIbQCoe53WXakv9gDLB3UYLaCzuFvVGGOnpcmlU/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=lambda+cas&submit=SIMBAD+search): B8Vn

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [19/09/2025](../../Osservazioni/20250919/Lambda_Cas.html)
