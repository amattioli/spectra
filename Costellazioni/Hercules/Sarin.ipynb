# %% [markdown]
# # Sarin - Delta [Herculis](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1U0o00G2q6YoQiIBwUIeKjoTsvo724ewbovCwBdFfPJw/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=sarin&submit=SIMBAD+search): A1IVn

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [06/06/2025](../../Osservazioni/20250606/Sarin.html)
