# %% [markdown]
# # [Theta Ophiuchi](../../Costellazioni/Ophiucus/Theta_Oph.html) del [30/08/2025](Index.html)

# %%
import sys
sys.path.append('../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=90.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-08-30T19:20:13.4925333Z
# - EndCapture=2025-08-30T20:05:32.2758547Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 30 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_thetaoph_20250830_806.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,8.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_thetaoph_20250830_806-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6000, 6200):.1f}")
# Out:
# SNR Reale stimato: 863.3

# %%
spectral_lines_summary = pd.read_csv('Theta Oph - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('Theta Oph - 2025-08-30.csv', usecols=[0, 1, 21], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.40,1.3))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.6,1.2))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.6,1.2))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.6,1.2))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.7,1.2))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.7,1.2))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.7,1.3))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.6,1.2))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('Theta Oph - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)

df
# Out:
# fwhm_use =  11.885365000000547
# amp = -6.376184506282132
# mu = 4101.2615919644995
# sigma = 0.48755592919547086
# gamma = 5.347898170679495
# offset = 1.007215651545738
# fwhm_use =  12.36077959999966
# amp = -6.449301335646764
# mu = 4340.14715647028
# sigma = 0.9620456772162254
# gamma = 5.593179273643151
# offset = 1.0028125426015637
# fwhm_use =  11.409950399999616
# amp = -5.447072271693321
# mu = 4861.22594759698
# sigma = 2.2443488945809404
# gamma = 4.359891807411056
# offset = 1.0039666886590526
# fwhm_use =  12.836194200000136
# amp = -6.129677905293203
# mu = 6563.587238602619
# sigma = 0.00027142066642745497
# gamma = 7.2553199389890075
# offset = 1.0010050302736826
# C:\Users\andrea\personal\physics\astro\spettroscopia\ipynb\Osservazioni\20250830\../../src\spectral_lines.py:57: RuntimeWarning: overflow encountered in multiply
#   return amp * voigt_profile(x - mean, sigma, gamma) + offset
# fwhm_use =  7.131218999999874
# amp = -0.07891531070994534
# mu = 4008.9280070101204
# sigma = 2.6204728225419873
# offset = 1.0083784854468472
# fwhm_use =  7.131218999999874
# amp = -0.170186103298934
# mu = 4025.647298286366
# sigma = 2.705514535876795
# offset = 1.0083784854468472
# fwhm_use =  6.655804399999397
# amp = -0.08788844863000889
# mu = 4143.373339389613
# sigma = 2.4179652623550676
# offset = 1.0073893214077145
# fwhm_use =  7.131218999999874
# amp = -0.11278355945447832
# mu = 4388.0154045666395
# sigma = 3.034850934407703
# offset = 1.0051810273109383
# fwhm_use =  7.131218999999874
# amp = -0.0427065665879228
# mu = 4712.798554320814
# sigma = 3.560239726715893
# offset = 1.0052971360467429
# fwhm_use =  7.60663360000035
# amp = -0.11185846093492315
# mu = 4921.972081483417
# sigma = 2.938952150466624
# offset = 1.0052927951650303
# fwhm_use =  7.857334789176471
# amp = -0.08531563594304699
# mu = 6679.151966912292
# sigma = 3.0155067620075697
# offset = 1.0026676556395702
# fwhm_use =  9.983706600000005
# amp = -0.011673281953499556
# mu = 6347.450639275788
# sigma = 3.7171579041699636
# offset = 1.0022045058050773
# fwhm_use =  7.495460381882353
# amp = -0.011748541602120133
# mu = 6372.125295901004
# sigma = 2.559867425034003
# offset = 1.0022838815831296
# fwhm_use =  7.131218999999874
# amp = -0.029957944962375787
# mu = 4552.476966298046
# sigma = 2.851405291305624
# offset = 1.005033150732686
# amp = -0.16428256675072037
# mu = 4470.831365573381
# sigma = 3.114524508934194
# offset = 1.0050181225070591
# amp = -0.045666958438204716
# mu = 4480.670687403186
# sigma = 3.3873911493548463
# offset = 1.0050181225070591
# amp = -0.02072221824888164
# mu = 4568.110846373784
# sigma = 2.1817504877610343
# offset = 1.005033150732686
# amp = -0.015965860561635216
# mu = 4575.287459238527
# sigma = 2.8085627471806647
# offset = 1.005033150732686
#            Line   Lambda min   Lambda fit        EW    EW_Err       FWHM  \
# 0     H$\delta$  4101.512024  4101.261592  6.330506  0.032255  10.826515
# 1     H$\gamma$  4339.694739  4340.147156  6.431213  0.029652  11.657938
# 2      H$\beta$  4861.224555  4861.225948  5.425551  0.039406  11.324983
# 3     H$\alpha$  6564.159652  6563.587239  6.123524  0.035917  14.510684
# 4     He I 4009  4009.281592  4008.928007  0.514052  0.011809   6.171213
# 5     He I 4026  4025.921103  4025.647298  1.144565  0.012449   6.371487
# 6     He I 4144  4143.348509  4143.373339  0.528779  0.008654   5.694308
# 7     He I 4388  4387.711613  4388.015405  0.853550  0.013824   7.147074
# 8     He I 4713  4712.419785  4712.798554  0.379114  0.044297   8.384365
# 9     He I 4922  4922.077624  4921.972081  0.819707  0.013083   6.921232
# 10    He I 6678  6678.734571  6679.151967  0.643164  0.014083   7.101518
# 11   Si II 6347  6347.370595  6347.450639  0.108527  0.014413   8.753907
# 12   Si II 6371  6371.141325  6372.125296  0.075214  0.012041   6.028488
# 13  Si III 4553  4552.205065  4552.476966  0.213049  0.009275   6.715059
# 14    He I 4471  4471.480000  4470.831366  1.276143  0.083912   7.334705
# 15   Mg II 4481  4481.260000  4480.670687  0.385819  0.113952   7.977306
# 16  Si III 4568  4567.870000  4568.110846  0.112759  0.014572   5.138022
# 17  Si III 4575  4574.780000  4575.287459  0.111837  0.015374   6.614165
#
#     FWHM_Err
# 0   0.065814
# 1   0.070622
# 2   0.066660
# 3   0.108363
# 4   0.129541
# 5   0.057765
# 6   0.093285
# 7   0.112565
# 8   1.856454
# 9   0.110001
# 10  0.174367
# 11  1.165516
# 12  1.425005
# 13  0.324947
# 14  0.208633
# 15  2.938545
# 16  0.614243
# 17  0.970250
