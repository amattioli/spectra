# %% [markdown]
# # [Vega - Alpha Lyrae](../../Costellazioni/Lyra/Vega.html) del [15/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=5.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-11-15T17:21:53.8796228Z
# - EndCapture=2024-11-15T17:31:06.3592641Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 100 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![pp_lights_stacked-resp-corr-self.png](attachment:pp_lights_stacked-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  390 - 540 nm

# %% [markdown]
# ![pp_lights_stacked-rect-390-540.png](attachment:pp_lights_stacked-rect-390-540.png)
