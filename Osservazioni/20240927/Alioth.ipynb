# %% [markdown]
# # [Alioth - Epsilon Ursae Majoris](../../Costellazioni/Ursa_Major/Alioth.html) del [27/09/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=10.000s
# - Brightness=5
# - Temperature=8.1
# - StartCapture=2024-09-27T19:06:34.9421066Z
# - EndCapture=2024-09-27T19:08:10.7683840Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00002.png](attachment:frame_00002.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00002-rect.png](attachment:frame_00002-rect.png)
