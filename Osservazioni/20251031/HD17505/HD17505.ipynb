# %% [markdown]
# # [HD 17505](../../../Costellazioni/Camelopardalis/HD17505.html) del [31/10/2025](../Index.html)

# %%
import sys
sys.path.append('../../../src')
import spectrum as spec
import pandas as pd

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=300.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-10-31T18:26:13.1782355Z
# - EndCapture=2025-10-31T20:06:24.6057121Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 20 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %%
raw_wavelength, raw_flux = spec.load("_hd17505_20251031_768.fit")
raw_flux = spec.cleanup_flux(raw_flux)
spec.simple_plot(raw_wavelength, raw_flux, wl_range = (3400, 7500), flux_range=(0.0,12.0))

# %% [markdown]
# ## Rectified Spectrum [download](_alkaid_20250808_874-rect)

# %%
wavelength, flux = spec.load("_hd17505_20251031_768-rect.fit")
flux = spec.cleanup_flux(flux)
print(f"SNR Reale stimato: {spec.calc_snr(wavelength, flux, 6710, 6810):.1f}")
# Out:
# SNR Reale stimato: 111.9

# %%
spectral_lines_summary = pd.read_csv('HD 17505 spec - Summary.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])
spectral_lines_all = pd.read_csv('HD 17505 spec - 2025-10-31.csv', usecols=[0, 1, 2], names=["name","class","wavelength"])

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_summary, (3700,6750), (0.25,1.35))

# %% [markdown]
# ### Zoom  370 - 400 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3680,4020), (0.70,1.15))

# %% [markdown]
# ### Zoom  400 - 430 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (3980,4320), (0.70,1.15))

# %% [markdown]
# ### Zoom 430 - 460 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4280,4620), (0.70,1.15))

# %% [markdown]
# ### Zoom  460 - 490 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4580,4920), (0.70,1.15))

# %% [markdown]
# ### Zoom  490 - 540 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (4880,5420), (0.75,1.15))

# %% [markdown]
# ### Zoom  540 - 600 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5380,6020), (0.70,1.15))

# %% [markdown]
# ### Zoom  600 - 670 nm

# %%
spec.plot_with_lines(wavelength, flux, spectral_lines_all, (5980,6720), (0.70,1.15))

# %% [markdown]
# ## Line Measures

# %%
from spectral_lines import estimate_continuum
from spectral_lines import fit_all_identified_lines

# %%
spectral_lines_df = pd.read_csv('HD 17505 spec - Measured.csv', names=["name","model","wavelength","group"])

spectral_lines = list(spectral_lines_df.itertuples(index=False, name=None))

line_window = 2.0          # angstroem tolerance for matching (+/- window)
smoothing_width = 3        # pixels for noise suppression
min_prominence = 0.01      # fraction of max flux

peak_wavelengths, peak_fluxes = spec.find_absorption_lines(
    wavelength, 
    flux, 
    smoothing_width = smoothing_width, 
    min_prominence = min_prominence )

identified_lines = spec.identify_absorption_lines(
    peak_wavelengths, 
    peak_fluxes, 
    spectral_lines, 
    z = 0.0, 
    line_window = line_window)

continuum_env = estimate_continuum(wavelength, flux, smooth_win_size=2, env_win_size = 15)

measures = fit_all_identified_lines(wavelength, flux, continuum_env, identified_lines)

df = pd.DataFrame(measures)
df = df.sort_values('Lambda fit')
df
# Out:
# fwhm_use =  9.0
# amp = -2.33490642809716
# mu = 4100.032142656862
# sigma = 2.556642323052786
# gamma = 1.6977853410767276
# offset = 0.998712026743395
# fwhm_use =  8.5
# amp = -2.3772865082862564
# mu = 4339.598965692936
# sigma = 2.750773473367374
# gamma = 1.4431549998053708
# offset = 0.9984084517955756
# fwhm_use =  9.0
# amp = -2.3438489230787654
# mu = 4860.365269027717
# sigma = 2.973189506109915
# gamma = 1.1541990139861724
# offset = 0.9988838011863285
# fwhm_use =  12.0
# amp = -2.9448910677250812
# mu = 6560.826885485199
# sigma = 3.335300144364011
# gamma = 2.7942223270811146
# offset = 0.9986363982694347
# fwhm_use =  12.5
# fwhm_use =  27.5
# amp = -0.08352371588822066
# mu = 4684.854770926486
# sigma = 3.315327233280239
# offset = 0.9989567776285488
# fwhm_use =  7.0
# amp = -0.028548789850380306
# mu = 4921.1361248470175
# sigma = 2.8011630140148975
# offset = 0.9987798899394268
# fwhm_use =  13.5
# amp = -0.05327965816429091
# mu = 6679.778402002787
# ...
