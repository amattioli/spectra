# %% [markdown]
# # HR8023 in [Cygnus](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento Righe](https://docs.google.com/spreadsheets/d/1wIuNGoZDbenOf2OmzGV4uBaaLjEdIGtOQXnL6oLfT8k/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=hr+8023&submit=SIMBAD+search): O6.5V((f))z

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [18/07/2025](../../Osservazioni/20250718/HR8023.html)
