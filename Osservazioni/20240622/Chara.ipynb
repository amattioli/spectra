# %% [markdown]
# # [Chara - Beta Canum Venaticorum](../../Costellazioni/Canes_Venatici/Chara.html) del [22/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=200
# - Exposure=20.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-22T22:01:15.4882542Z
# - EndCapture=2024-06-22T22:18:24.7913186Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dalla media di 8 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Cor Caroli della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-cor-caroli.png](attachment:meanprofil-resp-corr-cor-caroli.png)
