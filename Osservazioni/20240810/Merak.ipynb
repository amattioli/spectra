# %% [markdown]
# # [Merak - Beta Ursae Majoris](../../Costellazioni/Ursa_Major/Merak.html) del [10/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=15.000s
# - Brightness=5
# - Temperature=-0.1
# - StartCapture=2024-08-10T20:31:17.6177773Z
# - EndCapture=2024-08-10T20:57:17.6464992Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 8 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![meanprofil-resp-corr-self.png](attachment:meanprofil-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)
