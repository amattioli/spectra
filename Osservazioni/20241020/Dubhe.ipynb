# %% [markdown]
# # [Dubhe - Alpha Ursae Majoris](../../Costellazioni/Ursa_Major/Dubhe.html) del [20/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=30.000s
# - Brightness=5
# - Temperature=8.8
# - StartCapture=2024-10-20T17:37:57.1681759Z
# - EndCapture=2024-10-20T17:40:30.2701633Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![frame_00001.png](attachment:frame_00001.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![frame_00001-rect.png](attachment:frame_00001-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![frame_00001-rect-400-500.png](attachment:frame_00001-rect-400-500.png)

# %% [markdown]
# ### Zoom 500 - 600 nm

# %% [markdown]
# ![frame_00001-rect-500-600.png](attachment:frame_00001-rect-500-600.png)
