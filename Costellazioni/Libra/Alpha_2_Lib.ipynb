# %% [markdown]
# # Alpha 2 [Librae](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1SoOimciXLjUfkeasz2UCDgye2giMnRWAqj3BEC1c5D0/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=alfa+lib&submit=SIMBAD+search): kA2hA5mA4IV-V

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [28/06/2025](../../Osservazioni/20250628/Alpha_2_Lib.html)
