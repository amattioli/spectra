# %% [markdown]
# # [Theta Aurigae](../../Costellazioni/Auriga/Theta_Aur.html) del [29/01/2025](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=60.000s
# - Brightness=5
# - Temperature=-10
# - StartCapture=2025-01-29T18:53:59.3302558Z
# - EndCapture=2025-01-29T19:05:06.3479328Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 11 immagini. Applicati bias, dark e flat. Elaborazione con ISIS

# %% [markdown]
# ![_thetaaur_20250129_795.png](attachment:_thetaaur_20250129_795.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata da se stesso

# %% [markdown]
# ![_thetaaur_20250129_795-resp-corr-self.png](attachment:_thetaaur_20250129_795-resp-corr-self.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![_thetaaur_20250129_795-rect.png](attachment:_thetaaur_20250129_795-rect.png)

# %% [markdown]
# ### Zoom  370 - 410 nm

# %% [markdown]
# ![_thetaaur_20250129_795-rect-370-410.png](attachment:_thetaaur_20250129_795-rect-370-410.png)

# %% [markdown]
# ### Zoom  410 - 460 nm

# %% [markdown]
# ![_thetaaur_20250129_795-rect-410-460.png](attachment:_thetaaur_20250129_795-rect-410-460.png)

# %% [markdown]
# ### Zoom  460 - 530 nm

# %% [markdown]
# ![_thetaaur_20250129_795-rect-460-530.png](attachment:_thetaaur_20250129_795-rect-460-530.png)

# %% [markdown]
# ### Zoom  590 - 660 nm

# %% [markdown]
# ![_thetaaur_20250129_795-rect-590-660.png](attachment:_thetaaur_20250129_795-rect-590-660.png)
