# %% [markdown]
# # [5 Ursae Minoris](../../Costellazioni/Ursa_Minor/5_UMi.html) del [13/10/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=60.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-10-13T19:52:55.6275019Z
# - EndCapture=2024-10-13T20:03:01.4269860Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto da singola immagine

# %% [markdown]
# ![pp_lights_00006.png](attachment:pp_lights_00006.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_00006-rect.png](attachment:pp_lights_00006-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![pp_lights_00006-rect-400-500.png](attachment:pp_lights_00006-rect-400-500.png)

# %% [markdown]
# ### Zoom 500 - 600 nm

# %% [markdown]
# ![pp_lights_00006-rect-500-600.png](attachment:pp_lights_00006-rect-500-600.png)
