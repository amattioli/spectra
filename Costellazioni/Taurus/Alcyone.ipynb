# %% [markdown]
# # Alcyone - Eta [Tauri](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1eySzyq6bhC9wed3ZPsUOguV8Qt6J-6KQECadUuq82-Q/edit?usp=drive_link)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=alcyone&submit=SIMBAD+search): B7III

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [03/03/2025](../../Osservazioni/20250303/Alcyone.html)
