# %% [markdown]
# # [Muscida - Omicron Ursae Majoris](../../Costellazioni/Ursa_Major/Muscida.html) del [16/06/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=150
# - Exposure=25.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-06-16T20:39:46.4467858Z
# - EndCapture=2024-06-16T21:22:27.2292370Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 5 immagini

# %% [markdown]
# ![2024-06-16-2043_6-muscida%20spec_media-raw.png](attachment:2024-06-16-2043_6-muscida%20spec_media-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ![2024-06-16-2043_6-muscida%20spec_media-lin.png](attachment:2024-06-16-2043_6-muscida%20spec_media-lin.png)
