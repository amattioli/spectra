# %% [markdown]
# # CE Camelopardalis [29/04/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=250
# - Exposure=19.000s
# - Brightness=5
# - Temperature=-5
# - StartCapture=2024-04-29T19:38:46.7291857Z
# - EndCapture=2024-04-29T19:55:04.6348419Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 4 immagini

# %% [markdown]
# ![2024-04-29-1947_1-ce%20cam%20spec_media-raw.png](attachment:2024-04-29-1947_1-ce%20cam%20spec_media-raw.png)

# %% [markdown]
# ## Linear Spectrum

# %% [markdown]
# ![2024-04-29-1947_1-ce%20cam%20spec_media-lin.png](attachment:2024-04-29-1947_1-ce%20cam%20spec_media-lin.png)
