# %% [markdown]
# # [Navi - Gamma Cassiopeiae](../../Costellazioni/Cassiopeia/Navi.html) del [30/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=50
# - Exposure=18.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-30T22:42:01.4332043Z
# - EndCapture=2024-08-30T23:12:55.3328900Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Caph della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-caph.png](attachment:meanprofil-resp-corr-caph.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)
