# %% [markdown]
# # [Schedar - Alpha Cassiopeiae](../../Costellazioni/Cassiopeia/Schedar.html) del [30/08/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=100
# - Exposure=20.000s
# - Brightness=5
# - Temperature=0
# - StartCapture=2024-08-30T22:02:04.0929703Z
# - EndCapture=2024-08-30T22:36:22.7279329Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto come media di 10 immagini

# %% [markdown]
# ![meanprofil.png](attachment:meanprofil.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Alderamin della stessa serata

# %% [markdown]
# ![meanprofil-resp-corr-alderamin.png](attachment:meanprofil-resp-corr-alderamin.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![meanprofil-rect.png](attachment:meanprofil-rect.png)

# %% [markdown]
# ### Zoom 400 - 480 nm

# %% [markdown]
# ![meanprofil-rect-400-480.png](attachment:meanprofil-rect-400-480.png)

# %% [markdown]
# ### Zoom 480 - 560 nm

# %% [markdown]
# ![meanprofil-rect-480-560.png](attachment:meanprofil-rect-480-560.png)
