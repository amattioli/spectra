# %% [markdown]
# # [Hamal - Alpha Arietis](../../Costellazioni/Aries/Hamal.html) del [23/11/2024](Index.html)

# %% [markdown]
# ## Camera Settings

# %% [markdown]
# - Gain=0
# - Exposure=35.000s
# - Brightness=5
# - Temperature=-4.8
# - StartCapture=2024-11-23T18:14:00.6319442Z
# - EndCapture=2024-11-23T18:23:29.5692557Z

# %% [markdown]
# ## Raw Spectrum

# %% [markdown]
# Spettro ottenuto dcome media di 11 immagini

# %% [markdown]
# ![pp_lights_stacked.png](attachment:pp_lights_stacked.png)

# %% [markdown]
# ## Flux Corrected Spectrum

# %% [markdown]
# Spettro ottenuto dividendo il raw-spectrum per la risposta ricavata dallo spettro di Sheratan della stessa serata

# %% [markdown]
# ![pp_lights_stacked-resp-corr-sheratan.png](attachment:pp_lights_stacked-resp-corr-sheratan.png)

# %% [markdown]
# ## Rectified Spectrum

# %% [markdown]
# ![pp_lights_stacked-rect.png](attachment:pp_lights_stacked-rect.png)

# %% [markdown]
# ### Zoom  400 - 500 nm

# %% [markdown]
# ![pp_lights_stacked-rect-400-500.png](attachment:pp_lights_stacked-rect-400-500.png)

# %% [markdown]
# ### Zoom  500 - 600 nm

# %% [markdown]
# ![pp_lights_stacked-rect-500-600.png](attachment:pp_lights_stacked-rect-500-600.png)
