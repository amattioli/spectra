# %% [markdown]
# # HR8281 in [Cepheus](Index.html)

# %% [markdown]
# ## Descrizione

# %% [markdown]
# [Riconoscimento righe](https://docs.google.com/spreadsheets/d/1_DFdLJkr9eL6DrT0pLr9apTj9wbgTqxKAgqKdeJNsms/edit?gid=0#gid=0)

# %% [markdown]
# ## Classificazione

# %% [markdown]
# - Classificazione [Simbad](https://simbad.cds.unistra.fr/simbad/sim-basic?Ident=hr+8281&submit=SIMBAD+search): O6.0V((f))+O9:V
# - Classificazione [Bright Star Catalogue](https://vizier.cds.unistra.fr/viz-bin/VizieR-5?-ref=VIZ6a3c10511f66e&-out.add=.&-source=V/50/catalog&recno=8281): O6.5V((f))

# %% [markdown]
# ## Osservazioni

# %% [markdown]
# - [12/09/2025](../../Osservazioni/20250912/HR8281.html)
